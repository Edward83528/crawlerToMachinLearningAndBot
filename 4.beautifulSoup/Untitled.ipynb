# %%
#coding:utf-8
#65001
import requests
from bs4 import BeautifulSoup

rs = requests.session()
res = rs.get('https://news.ltn.com.tw/search?keyword=%E5%B7%9D%E6%99%AE&conditions=and&start_time=2018-10-20&end_time=2018-10-25&page=1')

html_data = res.text

soup = BeautifulSoup(html_data, "lxml")
for x in soup.find_all('a'):
    print(x.get('href'))
    #print(x.getText())
# Out:
# javascript::void(0)
# https://www.microsoftedgeinsider.com/zh-tw/download
# https://www.mozilla.org/zh-TW/firefox/new/
# https://www.google.com.tw/chrome/browser/desktop/index.html
# https://www.ltn.com.tw
# https://www.ltn.com.tw
# https://news.ltn.com.tw/list/breakingnews
# https://news.ltn.com.tw/list/breakingnews/popular
# https://news.ltn.com.tw/list/breakingnews/politics
# https://news.ltn.com.tw/list/breakingnews/society
# https://news.ltn.com.tw/list/breakingnews/life
# https://health.ltn.com.tw
# https://news.ltn.com.tw/list/breakingnews/world
# https://news.ltn.com.tw/list/breakingnews/local
# https://news.ltn.com.tw/list/breakingnews/novelty
# https://video.ltn.com.tw
# https://ec.ltn.com.tw
# https://ent.ltn.com.tw
# https://partners.ltn.com.tw
# https://auto.ltn.com.tw
# https://istyle.ltn.com.tw
# https://sports.ltn.com.tw
# https://3c.ltn.com.tw
# https://talk.ltn.com.tw
# https://playing.ltn.com.tw/
# https://food.ltn.com.tw
# https://estate.ltn.com.tw
# https://features.ltn.com.tw/
# http://www.taipeitimes.com/
# https://ltn_jobs.yes123.com.tw/index.asp
# https://www.facebook.com/m.ltn.tw/?fref=ts
# https://line.me/R/ti/p/%40ltnnews
# https://www.youtube.com/user/tvforltn
# https://opinion.ltn.com.tw/inform/complain_a1.php
# None
# https://www.ltn.com.tw/
# https://video.ltn.com.tw/m
# https://news.ltn.com.tw/list/breakingnews
# https://news.ltn.com.tw/list/breakingnews/popular
# https://news.ltn.com.tw/list/breakingnews/politics
# https://news.ltn.com.tw/list/breakingnews/society
# https://news.ltn.com.tw/list/breakingnews/life
# https://news.ltn.com.tw/list/breakingnews/world
# https://news.ltn.com.tw/list/breakingnews/local
# https://news.ltn.com.tw/list/breakingnews/novelty
# https://ec.ltn.com.tw/m
# https://ent.ltn.com.tw/m
# https://auto.ltn.com.tw/m
# https://istyle.ltn.com.tw/m
# https://sports.ltn.com.tw/m
# https://3c.ltn.com.tw/m
# https://talk.ltn.com.tw/
# https://playing.ltn.com.tw/m
# https://food.ltn.com.tw/m
# https://partners.ltn.com.tw
# https://health.ltn.com.tw/m
# https://estate.ltn.com.tw/
# https://features.ltn.com.tw/m
# https://service.ltn.com.tw/
# https://iservice.ltn.com.tw/app/app.html
# https://www.facebook.com/m.ltn.tw
# https://line.me/R/ti/p/%40ltnnews
# https://market.ltn.com.tw/m
# https://www.ltn.com.tw
# https://news.ltn.com.tw/search?keyword=川普&conditions=and&start_time=2018-10-20&end_time=2018-10-25&
# https://news.ltn.com.tw/news/world/breakingnews/2592412
# https://news.ltn.com.tw/news/business/breakingnews/2592342
# https://news.ltn.com.tw/news/business/breakingnews/2592064
# https://news.ltn.com.tw/news/business/breakingnews/2592213
# https://news.ltn.com.tw/news/politics/breakingnews/2592210
# https://news.ltn.com.tw/news/world/breakingnews/2592235
# https://news.ltn.com.tw/news/business/breakingnews/2591959
# https://news.ltn.com.tw/news/business/breakingnews/2591868
# https://news.ltn.com.tw/news/business/breakingnews/2591744
# https://news.ltn.com.tw/news/business/breakingnews/2591723
# https://news.ltn.com.tw/news/world/breakingnews/2591722
# https://news.ltn.com.tw/news/business/breakingnews/2591719
# https://news.ltn.com.tw/news/world/breakingnews/2591662
# https://news.ltn.com.tw/news/world/breakingnews/2591355
# https://news.ltn.com.tw/news/world/breakingnews/2591337
# None
# search?keyword=川普&conditions=and&start_time=2018-10-20&end_time=2018-10-25&page=2
# search?keyword=川普&conditions=and&start_time=2018-10-20&end_time=2018-10-25&page=3
# search?keyword=川普&conditions=and&start_time=2018-10-20&end_time=2018-10-25&page=2
# search?keyword=川普&conditions=and&start_time=2018-10-20&end_time=2018-10-25&page=11
# https://news.ltn.com.tw/news/entertainment/breakingnews/3178857
# https://news.ltn.com.tw/news/society/breakingnews/3178833
# https://news.ltn.com.tw/news/entertainment/breakingnews/3179266
# https://news.ltn.com.tw/news/world/breakingnews/3179072
# https://news.ltn.com.tw/news/society/breakingnews/3179178
# https://pv.ltn.com.tw/click?ano=2020051536081401
# https://market.ltn.com.tw
# https://market.ltn.com.tw
# https://pv.ltn.com.tw/click?ano=2020051330053527
# https://pv.ltn.com.tw/click?ano=2020052595440429
# https://pv.ltn.com.tw/click?ano=2020052654720245
# https://pv.ltn.com.tw/click?ano=2020052792074845
# https://pv.ltn.com.tw/click?ano=2020050869304301
# https://pv.ltn.com.tw/click?ano=2020052792244846
# https://www.facebook.com/m.ltn.tw/?fref=ts
# https://line.me/R/ti/p/%40ltnnews
# https://www.youtube.com/user/tvforltn
# javascript:void(0)
# https://news.ltn.com.tw/list/breakingnews/all
# https://news.ltn.com.tw/list/breakingnews/popular
# https://news.ltn.com.tw/list/breakingnews/politics
# https://news.ltn.com.tw/list/breakingnews/society
# https://news.ltn.com.tw/list/breakingnews/life
# https://news.ltn.com.tw/list/breakingnews/world
# https://news.ltn.com.tw/list/breakingnews/local
# https://news.ltn.com.tw/list/breakingnews/novelty
# https://video.ltn.com.tw
# https://ec.ltn.com.tw
# https://ent.ltn.com.tw
# https://partners.ltn.com.tw
# https://auto.ltn.com.tw
# https://istyle.ltn.com.tw
# https://sports.ltn.com.tw
# https://3c.ltn.com.tw
# https://talk.ltn.com.tw
# https://playing.ltn.com.tw/
# https://food.ltn.com.tw
# https://health.ltn.com.tw
# https://estate.ltn.com.tw
# https://features.ltn.com.tw
# http://www.taipeitimes.com/News
# https://service.ltn.com.tw/advertise
# https://market.ltn.com.tw
# http://invoice.etax.nat.gov.tw/
# http://www.taiwanlottery.com.tw/
# https://www.yes123.com.tw/admin/job_refer_comp_info.asp?p_id=5000225_52570683
# https://service.ltn.com.tw/RSS
# https://service.ltn.com.tw/about
# https://opinion.ltn.com.tw/inform/complain_1.php?type=3
# https://service.ltn.com.tw/copyright
# https://service.ltn.com.tw/privacy-policy
# https://service.ltn.com.tw/subscribe
# https://service.ltn.com.tw/contribute
# http://ubot.org.tw/
# http://www.lrsf.org.tw/
# https://www.ubot.com.tw/
# http://www.rslhotel.com/
# http://www.rslhotel.com/
# http://www.lscc.com.tw/
# https://www.yes123.com.tw/
# https://itunes.apple.com/tw/app/zi-you-shi-bao/id1060983848?l=zh&ls=1&mt=8
# https://play.google.com/store/apps/details?id=com.ltnnews.news
# https://health.ltn.com.tw/article/breakingnews/3179741
# https://health.ltn.com.tw/article/breakingnews/3179741
# https://ent.ltn.com.tw/news/breakingnews/3179921
# https://ent.ltn.com.tw/news/breakingnews/3179921
# https://ec.ltn.com.tw/article/breakingnews/3179801
# https://ec.ltn.com.tw/article/breakingnews/3179801
# https://news.ltn.com.tw/news/life/breakingnews/3179782
# https://news.ltn.com.tw/news/life/breakingnews/3179782
# https://news.ltn.com.tw/news/society/breakingnews/3179762
# https://news.ltn.com.tw/news/society/breakingnews/3179762
# https://ec.ltn.com.tw/article/breakingnews/3179754
# https://ec.ltn.com.tw/article/breakingnews/3179754
# https://sports.ltn.com.tw/news/breakingnews/3179597
# https://sports.ltn.com.tw/news/breakingnews/3179597
# https://ec.ltn.com.tw/article/breakingnews/3179724
# https://ec.ltn.com.tw/article/breakingnews/3179724
# //3c.ltn.com.tw/news/40530
# //3c.ltn.com.tw/news/40530
# https://ec.ltn.com.tw/article/breakingnews/3179560
# https://ec.ltn.com.tw/article/breakingnews/3179560

# %%
#coding:utf-8
#65001
import requests
from bs4 import BeautifulSoup

rs = requests.session()
res = rs.get('http://jumpin.cc/UUU/TestHtml/')
html_data = res.text

soup = BeautifulSoup(html_data, "lxml")
for x in soup.find_all('p', attrs={"class":"bold-paragraph"}):
    print(x.getText())
# Out:
#       Data Science:
#       David Blog
#
#
#       Machine Learning:
#       LnData Inc.

# %%
#coding:utf-8
#65001
import urllib.request
import json
import codecs
import sys
import argparse as ap
import time
import datetime
import requests
import random
from bs4 import BeautifulSoup as bs
from urllib.parse import quote

#python main.py 八仙塵爆 2015-06-27 2015-08-24 1
#def argParse():
#    parser=ap.ArgumentParser(description='Liberty Time Net Crawler')
#    parser.add_argument("keyword", help="Serch Keyword")
#    parser.add_argument("start_date", help="Start (2017-01-01)")
#    parser.add_argument("end_date", help="End (2017-01-02)")
#    parser.add_argument("pages", help="Pages")
#    return parser.parse_args()

#args=argParse()
#keyword = quote(args.keyword)
#start_date = args.start_date
#end_date = args.end_date
#pages = args.pages

keyword = quote('川普')
start_date = '2018-03-02'
end_date = '2018-03-05'
pages = '1'

def start_requests():
    if( len(start_date.split("-"))==3 and len(end_date.split("-"))==3) :
        SYear = start_date.split("-")[0]
        SMonth = start_date.split("-")[1]
        SDay = start_date.split("-")[2]
        EYear = end_date.split("-")[0]
        EMonth = end_date.split("-")[1]
        EDay = end_date.split("-")[2]

        urls = []
        for i in range(1,int(pages)+1):
            str_idx = ''+('%s' % i)
            str_rand = str(random.randint(1,99999))
            urls.append('http://news.ltn.com.tw/search?keyword='+keyword+'&conditions=and&SYear='+SYear+'&SMonth='+SMonth+'&SDay='+SDay+'&EYear='+EYear+'&EMonth='+EMonth+'&EDay='+EDay+'&page='+str_idx+'&rand='+str_rand+'')

        for url in urls:
            print (url)
            parseLtnNews(url)
            time.sleep(0.5)
    else:
        print ("Data format error.")


def request_uri(uri):
    header = {"User-Agent": 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.36'}
    rs = requests.session()
    res = rs.get(uri, headers=header)
    html_data =  res.text
    #r = requests.get(url=uri, headers={'Connection':'close'})
    return html_data


def parseLtnNews(uri):
    print(uri)
    html_data =  request_uri(uri)
    soup = bs(html_data,'html.parser')
    postdate = []
    link = []
    title = []
    body = []
    for ul_soup in soup.findAll('ul',attrs={"class":"searchlist boxTitle"}):
        for li_soup in ul_soup.findAll('li'):
        
            # TO DO 發文日期
            print(li_soup.getText())

            for span_soup in li_soup.findAll('li'):
            # TO DO 新聞內文摘要
                print(li_soup)

        # TO DO 新聞標題、新聞連結
                for a_soup in li_soup.findAll('a',attrs={"class":"tit"}):
                    tmp_body = ''
                    tle = a_soup.getText().replace("\n","").strip()
                    lnk = a_soup.get('href')
                    #print(lnk)
                    title.append(tle.strip())
                    link.append(lnk)


    current = 0
    print(str(len(postdate)))
    while current < len(postdate):
        print(title[current])
        items.append({
              "title": title[current],
              "link":link[current],
              "body":body[current],
              "postdate":postdate[current],
              "updatetime":datetime.datetime.now().strftime('%Y-%m-%d')
          })
        current+=1

if __name__ == '__main__':
    items = []
    start_requests();
    row_json = json.dumps(items, ensure_ascii=False)
    file = codecs.open(urllib.parse.unquote(keyword)+'.json', 'w', encoding='utf-8')
    file.write(row_json)
    file.close()
  
    print("Done")
# Out:
# http://news.ltn.com.tw/search?keyword=%E5%B7%9D%E6%99%AE&conditions=and&SYear=2018&SMonth=03&SDay=02&EYear=2018&EMonth=03&EDay=05&page=1&rand=65292
# http://news.ltn.com.tw/search?keyword=%E5%B7%9D%E6%99%AE&conditions=and&SYear=2018&SMonth=03&SDay=02&EYear=2018&EMonth=03&EDay=05&page=1&rand=65292
#
# 2020-05-28 13:11
# 香港眾志：美國不排除本週暫停香港獨立關稅區地位
# 冠聰今表示，港版國安法是促使龐皮歐作出宣示的最後因素。羅冠聰引述美方消息人士指出，美國總統川普本週稍晚會宣布暫停香港「獨立關稅區」地位，促使北京當局改變對香港的政策方針，讓香港重新恢復自治地位。
#
# 香港...
#
#
# 2020-05-28 12:44
# 日本答應購買過剩人工呼吸器 川普開心「隨時都可以出貨」
# 應醫療器材，美國於今年3月大量製造人工呼吸器，卻發生製作太多的困擾，如今日本答應購買，據傳川普對此相當高興。
#
# 《朝日新聞中文網》報導，美國總統川普於3月份時，指示通用汽車等企業大量生產人工呼吸...
#
#
# 2020-05-28 12:20
# 風雨欲來！觀望氣氛濃厚 台幣中午暫收30.028元
# 貶，台股表現、外資動向將是關鍵。
#
#
# 中國強推「港版國安法」，使美中對立情勢升高，美國總統川普先是放話，質疑香港金融中心地位，表示本週將採取動作，國務卿龐皮歐則表示，27日向美國國會報告，香港不再擁有自...
#
#
# 2020-05-28 11:13
# 川普槓上推特 祖克柏表態：臉書不成為「事實仲裁者」
#
#
#
# 〔財經頻道／綜合報導〕推特（Twitter）日前將川普的2則貼文標記為「不實訊息」，讓川普大為光火，直批這是「扼殺言論自由」，揚言強制關閉社群平台。對此，同樣管理社群平台的臉書執行長祖克柏...
#
#
# 2020-05-28 11:09
# 中國態度不會動搖！分析師：美方威脅也擋不住港版國安法
# 」（Lowy Institute）研究員卡薩姆（Natasha Kassam）指出，他認為川普和美國政府可以選擇撤銷部分給予香港的特殊優惠待遇，但他也表示這是很重大的抉擇，且只能用1次，也不確定能確實發...
#
#
# 2020-05-28 10:34
# 中國強推「港版國安法」 美助卿：川普有一連串制裁清單
# 通過「港版國安法」，美國國務院亞太事務助理國務卿史迪威（David Stilwell）說，川普總統有回應中國的一連串清單，包括簽證和經濟制裁。
#
# 綜合媒體報導，史迪威27日在電話簡報上表示，對於北京推翻...
#
#
# 2020-05-28 10:22
# 怒槓推特！白宮發言人：川普將簽署有關社群媒體的行政命令
# 〔即時新聞／綜合報導〕推特日前將美國總統川普的推文標記為不實訊息，讓川普大為光火，甚至揚言要關閉社群媒體平台。白宮發言人稍早表示，川普即將簽署一份有關社群媒體的行政命令，但並未透露細節。...
#
#
# 2020-05-28 10:17
# 民主黨總統參選人拜登「撐港」︰美國反對中國鎮壓
# 「港版國安法」，香港將失去原有的高度自治權，一國兩制形同破局。除美國總統兼共和黨總統參選人川普（Donald Trump）揚言將就香港問題對中國進行制裁，而民主黨總統參選人拜登的高級顧問布林肯（Anto...
#
#
# 2020-05-28 10:15
# 制裁中國「港版國安法」來硬的？彭博：川普面臨兩難選項
# 的自治地位，因此考慮終止給予香港的特殊貿易待遇，但目前尚未有個統一正式聲明。《彭博》指出，川普正面臨1項艱難的選擇，即美國懲罰北京是否「來硬的」，或是選擇相對溫和措施。
#
#
# 《彭博》指出，川普可...
#
#
# 2020-05-28 09:01
# 美中緊張關係再度升溫 國際油價下跌
# 再度升溫，在龐皮歐宣布香港不再有足夠自治、無法繼續享有美國給予的特殊貿易待遇後。外界猜測，川普政府正在考慮中止香港出口至美國享有的優惠關稅稅率，以作為對中國擬強推「港版國安法」的強硬回應之一。...
#
#
# 2020-05-28 08:08
# 美國務卿宣布香港特殊貿易待遇恐中止  川普料將強硬回應港版國安法
# ，在美國國務卿龐皮歐宣布香港不再有足夠自治、無法繼續享有美國給予的特殊貿易待遇後，據透露，川普政府正在考慮中止香港出口至美國享有的優惠關稅稅率，以作為對中國擬強推「港版國安法」的強硬回應之一。
#
#
# 知情...
#
#
# 2020-05-28 07:45
# 美眾院通過「新疆人權法案」 要求政府制裁中國官員
# 新疆人權法案），要求美國政府對壓迫新疆維吾爾族的中國官員實施制裁，法案將送交白宮待美國總統川普簽署。
#
# 綜合媒體報導，美國眾議院以413票贊成、1票反對通過這項法案，投票是根據本月制定的臨時規則進行的首...
#
#
# 2020-05-28 06:38
# 稅率將和中國一樣！ 路透：美考慮中止香港特別關稅優惠
# 自治，無法繼續享有美國的特殊貿易待遇。儘管龐皮歐沒有透露要做出何種行動，但《路透》報導稱，川普政府正在考慮取消美國對香港的關稅特殊待遇。
#
# 龐皮歐27日聲明指出，他已向國會證實，香港無法根據「美國－香港...
#
#
# 2020-05-28 05:53
# 推特是親中共魔鬼？連署請白宮查「紅色背景」獨董李飛飛
# 獨立董事，加強人工智慧技術、打擊假消息，不過有帳號疑似揭發李飛飛紅色背景而被註銷，美國總統川普推文近日被推特標記「不實訊息」也再度引起話題。美國白宮請願連署網站上，有人就對此發起調查李飛飛的連署活動。
# ...
#
#
# 2020-05-28 05:51
# 高度自治不再 龐皮歐：香港將失去美國特殊貿易待遇
# 獨立關稅區」；美國在「一國兩制」框架下，支持香港的人權、民主與自治。
#
# 美國國會去年通過、川普總統簽署生效的「香港人權民主法」規定，國務院至少每年一次要向國會證明，香港仍享有足夠的自治，使之能繼續獲得美...
#
# 0
# Done
