# %%
#coding:utf-8
#65001
import urllib.request
import json
import codecs
import sys
import argparse as ap
import time
import datetime
import requests
from bs4 import BeautifulSoup as bs
from urllib.parse import quote

#python main.py 八仙塵爆 2015-06-27 2015-08-24 1
#def argParse():
#    parser=ap.ArgumentParser(description='Liberty Time Net Crawler')
#    parser.add_argument("keyword", help="Serch Keyword")
#    parser.add_argument("start_date", help="Start (2017-01-01)")
#    parser.add_argument("end_date", help="End (2017-01-02)")
#    parser.add_argument("pages", help="Pages")
#    return parser.parse_args()

#args=argParse()
#keyword = quote(args.keyword)
#start_date = args.start_date
#end_date = args.end_date
#pages = args.pages

keyword = quote('八仙塵爆')
start_date = '2015-06-27'
end_date = '2015-08-24'
pages = '1'

def start_requests():
    if( len(start_date.split("-"))==3 and len(end_date.split("-"))==3) :
        SYear = start_date.split("-")[0]
        SMonth = start_date.split("-")[1]
        SDay = start_date.split("-")[2]
        EYear = end_date.split("-")[0]
        EMonth = end_date.split("-")[1]
        EDay = end_date.split("-")[2]
        urls = []
        for i in range(1,int(pages)+1):
            str_idx = ''+('%s' % i)
            urls.append('http://news.ltn.com.tw/search?keyword='+keyword+'&conditions=and&SYear='+SYear+'&SMonth='+SMonth+'&SDay='+SDay+'&EYear='+EYear+'&EMonth='+EMonth+'&EDay='+EDay+'&page='+str_idx+'')

        for url in urls:
            print (url)
            parseLtnNews(url)
            time.sleep(0.5)
    else:
        print ("Data format error.")

def request_uri(uri):
    header = {"User-Agent": 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.36'}
    rs = requests.session()
    res = rs.get(uri, headers=header)
    html_data =  res.text
    #r = requests.post(url=uri, headers={'Connection':'close'})
    return html_data

def parseLtnNews(uri):
    html_data =  request_uri(uri)
    soup = bs(html_data,'html.parser')
    for ul_soup in soup.findAll('ul',attrs={"id":"newslistul"}):
        items.append({"uri":uri,"ul_soup":str(ul_soup),"updatetime":datetime.datetime.now().strftime('%Y-%m-%d')})
        # TO DO


    
    
    
    
if __name__ == '__main__':
    items = []
    start_requests();
    row_json = json.dumps(items, ensure_ascii=False)
    file = codecs.open(urllib.parse.unquote(keyword)+'.json', 'w', encoding='utf-8')
    file.write(row_json)
    file.close()
  

    print("Done")
# Out:
# http://news.ltn.com.tw/search?keyword=%E5%85%AB%E4%BB%99%E5%A1%B5%E7%88%86&conditions=and&SYear=2015&SMonth=06&SDay=27&EYear=2015&EMonth=08&EDay=24&page=1
# <ul class="searchlist" id="newslistul">
# <li>
# <a class="immtag chan" data-desc="T:0:地方" href="list/newspaper/local/20170828">地方</a><span>2015-08-24</span>
# <a class="tit" data-desc="T:0:先嗇宮普度 為塵爆罹難者超度" href="news/local/paper/909371">
# <p>先嗇宮普度 為塵爆罹難者超度</p>
# </a>
# <p>舉行中元普度法會，昨天舉行豎幡儀式，昭告「好兄弟」前來法會「聽經聞法」，享用供品，現場也替<strong>八仙塵爆</strong>罹難者設牌位超度。
# 昨天豎幡儀式由先嗇宮董事長李乾龍、輪值爐主奕壽里長周政宏...</p>
# </li>
# <li>
# <a class="immtag chan" data-desc="T:1:社會" href="list/breakingnews/society">社會</a><span>2015-08-23 21:04</span>
# <a class="tit" data-desc="T:1:全身60%灼傷 塵暴傷者麵包師傅林獻桐將出院" href="news/society/breakingnews/1421646">
# <p>全身60%灼傷 塵暴傷者麵包師傅林獻桐將出院</p>
# </a>
# <p>〔即時新聞／綜合報導〕<strong>八仙塵爆</strong>即將屆滿2個月，許多傷患仍在醫院接受治療、復健，傷者之一的蛋糕師傅林獻桐靠著堅強意志力，即將出院，林獻桐也說，經過這次的事件，未來一定多花時間陪老...</p>
# </li>
# <li>
# <a class="immtag chan" data-desc="T:2:生活" href="list/breakingnews/life">生活</a><span>2015-08-23 19:34</span>
# <a class="tit" data-desc="T:2:秦偉：傷患只要打氣 哪在乎三等親、四等親？" href="news/life/breakingnews/1421581">
# <p>秦偉：傷患只要打氣 哪在乎三等親、四等親？</p>
# </a>
# <p>〔即時新聞／綜合報導〕藝人秦偉昨前往中國醫藥大學附設醫院欲探視<strong>八仙塵爆</strong>傷患，但因非三等親遭院方拒絕，竟在醫院內咆哮，影片PO網後引起撻伐。秦偉今表示，希望外界將心比心，傷患只希...</p>
# </li>
# <li>
# <a class="immtag chan" data-desc="T:3:生活" href="list/breakingnews/life">生活</a><span>2015-08-23</span>
# <a class="tit" data-desc="T:3:燒燙傷患者須高熱量 多補充蛋白質" href="news/life/paper/909188">
# <p>燒燙傷患者須高熱量 多補充蛋白質</p>
# </a>
# <p>文／曾涵郁
# 去年的高雄氣爆和今年的<strong>八仙塵爆</strong>意外，增加不少燒燙傷病患，如能適當補充營養，將有助於傷口癒合及早日康復。
# ◎熱量
# 燒燙傷病患所需熱量跟年齡、性別、體重和燒燙傷面...</p>
# </li>
# <li>
# <a class="immtag chan2" data-desc="T:4:娛樂" href="list/breakingnews/entertainment">娛樂</a><span>2015-08-23</span>
# <a class="tit" data-desc="T:4:林昕陽為了歌迷 日花40萬" href="news/entertainment/paper/909006">
# <p>林昕陽為了歌迷 日花40萬</p>
# </a>
# <p>由1名女歌迷以6萬元得標，林昕陽宣布要將該筆款項捐給陽光基金會，並演唱《眼裡的陽光》，鼓勵<strong>八仙塵爆</strong>的傷患：「希望他們能堅強，趕快復元好起來。」...</p>
# </li>
# <li>
# <a class="immtag chan" data-desc="T:5:生活" href="list/breakingnews/life">生活</a><span>2015-08-23</span>
# <a class="tit" data-desc="T:5:塵爆樂觀男孩出院 提前慶生" href="news/life/paper/908962">
# <p>塵爆樂觀男孩出院 提前慶生</p>
# </a>
# <p>〔記者翁聿煌／新北報導〕<strong>八仙塵爆</strong>即將屆滿兩個月，在雙和醫院治療的呂紹熙昨天出院，醫院醫護人員特別為他準備廿歲生日蛋糕，提前歡度生日及出院歡送會，院方表示，呂紹熙積極的態度，是對...</p>
# </li>
# <li>
# <a class="immtag chan" data-desc="T:6:社會" href="list/breakingnews/society">社會</a><span>2015-08-22 18:20</span>
# <a class="tit" data-desc="T:6:出院了！&lt;strong&gt;八仙塵爆&lt;/strong&gt;燒傷50% 呂紹熙吹蠟蠋慶20歲" href="news/society/breakingnews/1420780">
# <p>出院了！<strong>八仙塵爆</strong>燒傷50% 呂紹熙吹蠟蠋慶20歲</p>
# </a>
# <p>〔記者翁聿煌／新北報導〕<strong>八仙塵爆</strong>即將屆滿兩個月，在雙和醫院治療的呂紹熙今天出院，醫護人員特別為他準備20歲生日蛋糕，提前歡度生日及出院歡送會，恭喜紹熙經歷急診入院、清創、植皮、...</p>
# </li>
# <li>
# <a class="immtag chan" data-desc="T:7:地方" href="list/newspaper/local/20170828">地方</a><span>2015-08-22</span>
# <a class="tit" data-desc="T:7:麻將、紙牌、六合彩 普度法會「娛樂」好兄弟" href="news/local/paper/908757">
# <p>麻將、紙牌、六合彩 普度法會「娛樂」好兄弟</p>
# </a>
# <p>、冤親債主等好好享用一番。
# 今年廟方以「功德海」慈航普度大法船為主軸，盼讓近來接連發生的<strong>八仙塵爆</strong>、天津爆炸、泰國爆炸案等受難者，可以乘著法船脫離苦海，並開放信眾到圍繞法船周圍...</p>
# </li>
# <li>
# <a class="immtag chan2" data-desc="T:8:娛樂" href="list/breakingnews/entertainment">娛樂</a><span>2015-08-22</span>
# <a class="tit" data-desc="T:8:塵爆傷者守諾 坐輪椅來看二姊" href="news/entertainment/paper/908714">
# <p>塵爆傷者守諾 坐輪椅來看二姊</p>
# </a>
# <p>，已有超過16萬人次在二姊演唱會上透過她的歌聲得到感動，每場台上台下都有感人故事，昨晚更有<strong>八仙塵爆</strong>傷者王捷垠坐著輪椅來看演出，他原本就搶買到二姊的門票，卻因塵爆受傷住院，他曾樂...</p>
# </li>
# <li>
# <a class="immtag chan" data-desc="T:9:生活" href="list/breakingnews/life">生活</a><span>2015-08-22</span>
# <a class="tit" data-desc="T:9:「能動，真的很幸福」 八仙傷者宋亭緯出院" href="news/life/paper/908674">
# <p>「能動，真的很幸福」 八仙傷者宋亭緯出院</p>
# </a>
# <p>〔記者蔡淑媛、賴筱桐／綜合報導〕全身四十五％燒傷的<strong>八仙塵爆</strong>傷者宋亭緯昨天出院，直呼：「活著不是一件簡單的事，要好好珍惜！」至於奇蹟男孩呂意銘，其全身燒傷九十％未經植皮已減少到十...</p>
# </li>
# <li>
# <a class="immtag chan" data-desc="T:10:政治" href="list/breakingnews/politics">政治</a><span>2015-08-21 22:13</span>
# <a class="tit" data-desc="T:10:蘇迪勒風災過後 朱立倫施政不滿意度創新高" href="news/politics/breakingnews/1420086">
# <p>蘇迪勒風災過後 朱立倫施政不滿意度創新高</p>
# </a>
# <p>調結果，朱立倫的施政不滿意度是上任以來最高的一次。TVBS民調中心分析認為，風災救災不力、<strong>八仙塵爆</strong>事件處理狀況，以及面對國民黨內提名的態度，都有可能是影響這次調查結果的原因。...</p>
# </li>
# <li>
# <a class="immtag chan" data-desc="T:11:生活" href="list/breakingnews/life">生活</a><span>2015-08-21 21:24</span>
# <a class="tit" data-desc="T:11:八仙傷者宋亭緯出院 奇蹟男孩呂意銘站起來了" href="news/life/breakingnews/1420112">
# <p>八仙傷者宋亭緯出院 奇蹟男孩呂意銘站起來了</p>
# </a>
# <p>〔記者蔡淑媛／台中報導〕<strong>八仙塵爆</strong>傷者宋亭緯全身四十五%燒傷，今天出院，直呼「活著不是一件簡單的事，要好好珍惜！」感謝醫護人員呵護，也鼓勵傷友一起加油，回家後他將持續復健也能上學...</p>
# </li>
# <li>
# <a class="immtag chan" data-desc="T:12:政治" href="list/breakingnews/politics">政治</a><span>2015-08-21 20:35</span>
# <a class="tit" data-desc="T:12:洪辦發言人幫駁斥 段宜康：傻傻的小傢伙" href="news/politics/breakingnews/1420032">
# <p>洪辦發言人幫駁斥 段宜康：傻傻的小傢伙</p>
# </a>
# <p>賦予她的權力，把宜蘭的醫療資源都刪光，並舉燒傷病床為例，原要配置的4個燒傷病床也被刪除，而<strong>八仙塵爆</strong>卻有11名宜蘭年輕人受傷。並問道：「洪秀柱女士，您對您乾爸爸之外的宜蘭人說句話...</p>
# </li>
# <li>
# <a class="immtag chan2" data-desc="T:13:娛樂" href="list/breakingnews/entertainment">娛樂</a><span>2015-08-21 20:10</span>
# <a class="tit" data-desc="T:13:（影音）偶像約定鼓勵！塵爆傷者坐輪椅看江蕙" href="news/entertainment/breakingnews/1420052">
# <p>（影音）偶像約定鼓勵！塵爆傷者坐輪椅看江蕙</p>
# </a>
# <p>
#
#
#
#
#
# 〔記者陳慧玲／台北報導〕「二姊一定會等著你的。」7月中的一句約定，讓<strong>八仙塵爆</strong>傷者帶著二姊的鼓勵努力復健，今晚「二姊」江蕙在小巨蛋的第15場「祝福」演唱會，傷者王捷垠...</p>
# </li>
# <li>
# <a class="immtag chan" data-desc="T:14:生活" href="list/breakingnews/life">生活</a><span>2015-08-21 11:55</span>
# <a class="tit" data-desc="T:14:高溫燈光害&lt;strong&gt;八仙塵爆&lt;/strong&gt;？侯友宜：報告還沒出爐" href="news/life/breakingnews/1419407">
# <p>高溫燈光害<strong>八仙塵爆</strong>？侯友宜：報告還沒出爐</p>
# </a>
# <p>〔記者賴筱桐／新北報導〕<strong>八仙塵爆</strong>發生至今近2個月，媒體報導，檢警經密集實驗，排除菸蒂、靜電、打火機等因素，認為燈光束高溫加上民眾奔逃擾動氣流，助長高密度粉塵引燃爆炸。但上述推論...</p>
# </li>
# </ul>
# Done
