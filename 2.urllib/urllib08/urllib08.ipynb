# %% [markdown]
# # urllib - split - 自由時報關鍵字,內文摘要 - 輸出JSON檔案

# %%
#coding:utf-8
#65001
import urllib.request
import json
import codecs
import sys
import argparse as ap
import time
import datetime
from urllib.parse import quote
#以下註解拿掉可以用py執行下參數
# def argParse():
#     parser=ap.ArgumentParser(description='Liberty Time Net Crawler')
#     parser.add_argument("keyword", help="Serch Keyword")
#     parser.add_argument("start_date", help="Start (2017-01-01)")
#     parser.add_argument("end_date", help="End (2017-01-02)")
#     parser.add_argument("pages", help="Pages")
#     return parser.parse_args()

# args=argParse()
# keyword = quote(args.keyword)
# start_date = args.start_date
# end_date = args.end_date
# pages = args.pages

keyword = quote('周杰倫')
start_date = '2020-04-14'
end_date = '2019-04-15'
pages = '2'

def start_requests():
    start_list = start_date.split("-")
    end_list = end_date.split("-")
    SYear = ''
    SMonth = ''
    SDay = ''
    EYear = ''
    EMonth = ''
    EDay = ''
    if(len(start_list)==3) and (len(end_list)==3):
        SYear = start_list[0]
        SMonth = start_list[1]
        SDay = start_list[2]
        EYear = end_list[0]
        EMonth = end_list[1]
        EDay = end_list[2]
    else:
        print ("Date format error.")
  
    urls = []
    for i in range(1,int(pages)+1):
        str_idx = ''+('%s' % i)
        #http://news.ltn.com.tw/search?keyword=蘋果&conditions=and&SYear=2018&SMonth=03&SDay=01&EYear=2018&EMonth=03&EDay=05&page=1
        api = 'http://news.ltn.com.tw/search?keyword='+keyword+'&conditions=and&SYear='+SYear+'&SMonth='+SMonth+'&SDay='+SDay+'&EYear='+EYear+'&EMonth='+EMonth+'&EDay='+EDay+'&page='+str_idx+''
        urls.append(api)
        print('http://news.ltn.com.tw/search?keyword='+keyword+'&conditions=and&SYear='+SYear+'&SMonth='+SMonth+'&SDay='+SDay+'&EYear='+EYear+'&EMonth='+EMonth+'&EDay='+EDay+'&page='+str_idx+'')
        for url in urls:
            #print (url)
            parseLtnNews(url)
            time.sleep(0.5)


def parseLtnNews(uri):
    handle = urllib.request.urlopen(uri)
    encoding = handle.headers.get_content_charset()
    html_data =  handle.read().decode(encoding)
    aryTemp01 = html_data.split('class="searchlist boxTitle"')
    if len(aryTemp01)>1:
        for a in aryTemp01[1].split('<li>'):
            title = ''
            link = ''
            body = ''
            postdate = ''
            aryTemp02 = a.split('<p>')
            if len(aryTemp02)>1:
                body = aryTemp02[1].split('</p>')[0].replace("\n","").replace("<strong>","").replace("</strong>","")
                #print(body)
            aryTemp02 = a.split('class="tit" href="')
            if len(aryTemp02)>1:
                title = aryTemp02[1].split('">')[1].split("</a>")[0].replace("\n","").replace("<strong>","").replace("</strong>","")
                print(title)
                aryTemp03 = aryTemp02[1].split('"')
                link = aryTemp03[0]
                print(link)
            aryTemp02 = a.split('<span>')
            if len(aryTemp02)>1:
                postdate = aryTemp02[1].split('</span>')[0].replace("&nbsp;","")[:10]
                print(postdate)
            if len(title)>1:
                items.append({
                    "title": title,
                    "link":link,
                    "body":body,
                    "postdate":postdate,
                    #"updatetime":datetime.datetime.now(),  # MongoDB
                    "updatetime":datetime.datetime.now().strftime('%Y-%m-%d')
                    })
        

if __name__ == '__main__':
    items = []
    start_requests();
    row_json = json.dumps(items, ensure_ascii=False)
    file = codecs.open(urllib.parse.unquote(keyword)+'.json', 'w', encoding='utf-8')
    #file = codecs.open('out.json', 'w', encoding='utf-8')
    file.write(row_json)
    file.close()
    #print(row_json)
    print("Done")
# Out:
# http://news.ltn.com.tw/search?keyword=%E5%91%A8%E6%9D%B0%E5%80%AB&conditions=and&SYear=2020&SMonth=04&SDay=14&EYear=2019&EMonth=04&EDay=15&page=1
# 自由廣場》自由 台港流行文化差異所在
# https://news.ltn.com.tw/news/opinion/paper/1375542
# 2020-05-27
# 蕭敬騰進軍手搖飲  親友求職萌生發展副業
# https://news.ltn.com.tw/news/entertainment/paper/1374895
# 2020-05-25
# （影音）蕭敬騰飲料店開幕吸人潮 曝林俊傑超真實反應
# https://news.ltn.com.tw/news/entertainment/breakingnews/3175805
# 2020-05-24
# 阿信哭哭！男神合體獨遭放鳥 周董、JJ揭真相
# https://news.ltn.com.tw/news/entertainment/breakingnews/3174711
# 2020-05-23
# 《怕天王被消音》蕭敬騰喝咖啡超省話 避談約滿動向
# https://news.ltn.com.tw/news/entertainment/paper/1374509
# 2020-05-23
# JJ、周董5大男神奇蹟合照！網驚呆：唐鳳來了
# https://news.ltn.com.tw/news/entertainment/breakingnews/3174343
# 2020-05-22
# 直擊！老蕭無預警突襲飲料店 歌迷塞爆西門町
# https://news.ltn.com.tw/news/entertainment/breakingnews/3174195
# 2020-05-22
# （影音）老蕭開腔了！華納12年約滿跳槽環球？親回合約動向
# https://news.ltn.com.tw/news/entertainment/breakingnews/3174153
# 2020-05-22
# 麗絲Liz告白周董 當直播主日進20萬
# https://news.ltn.com.tw/news/entertainment/paper/1374037
# 2020-05-21
# 混血魔術師PK周董 徒手噴火焰烤和牛
# https://news.ltn.com.tw/news/entertainment/paper/1374030
# 2020-05-21
# （影音）麗絲Liz當直播主爽被打賞20萬 520大膽告白周杰倫
# https://news.ltn.com.tw/news/entertainment/breakingnews/3172063
# 2020-05-20
# 跟偶像周杰倫共進晚餐   片寄涼太變迷弟害羞告白
# https://news.ltn.com.tw/news/entertainment/breakingnews/3171992
# 2020-05-20
# 周董邁入中年怎麼了？ 陳沂膽大酸嗆剛愎自用
# https://news.ltn.com.tw/news/entertainment/breakingnews/3169875
# 2020-05-19
# 小彭于晏神結合古典與流行   李齊把浴缸變舞台
# https://news.ltn.com.tw/news/entertainment/paper/1373518
# 2020-05-19
# 李建軒創作致敬周董 22首經典曲全入列
# https://news.ltn.com.tw/news/entertainment/paper/1373304
# 2020-05-18
# © 2020 The
# http://news.ltn.com.tw/search?keyword=%E5%91%A8%E6%9D%B0%E5%80%AB&conditions=and&SYear=2020&SMonth=04&SDay=14&EYear=2019&EMonth=04&EDay=15&page=2
# 自由廣場》自由 台港流行文化差異所在
# https://news.ltn.com.tw/news/opinion/paper/1375542
# 2020-05-27
# 蕭敬騰進軍手搖飲  親友求職萌生發展副業
# https://news.ltn.com.tw/news/entertainment/paper/1374895
# 2020-05-25
# （影音）蕭敬騰飲料店開幕吸人潮 曝林俊傑超真實反應
# https://news.ltn.com.tw/news/entertainment/breakingnews/3175805
# 2020-05-24
# 阿信哭哭！男神合體獨遭放鳥 周董、JJ揭真相
# https://news.ltn.com.tw/news/entertainment/breakingnews/3174711
# 2020-05-23
# 《怕天王被消音》蕭敬騰喝咖啡超省話 避談約滿動向
# https://news.ltn.com.tw/news/entertainment/paper/1374509
# 2020-05-23
# JJ、周董5大男神奇蹟合照！網驚呆：唐鳳來了
# https://news.ltn.com.tw/news/entertainment/breakingnews/3174343
# 2020-05-22
# 直擊！老蕭無預警突襲飲料店 歌迷塞爆西門町
# https://news.ltn.com.tw/news/entertainment/breakingnews/3174195
# 2020-05-22
# （影音）老蕭開腔了！華納12年約滿跳槽環球？親回合約動向
# https://news.ltn.com.tw/news/entertainment/breakingnews/3174153
# 2020-05-22
# 麗絲Liz告白周董 當直播主日進20萬
# https://news.ltn.com.tw/news/entertainment/paper/1374037
# 2020-05-21
# 混血魔術師PK周董 徒手噴火焰烤和牛
# https://news.ltn.com.tw/news/entertainment/paper/1374030
# 2020-05-21
# （影音）麗絲Liz當直播主爽被打賞20萬 520大膽告白周杰倫
# https://news.ltn.com.tw/news/entertainment/breakingnews/3172063
# 2020-05-20
# 跟偶像周杰倫共進晚餐   片寄涼太變迷弟害羞告白
# https://news.ltn.com.tw/news/entertainment/breakingnews/3171992
# 2020-05-20
# 周董邁入中年怎麼了？ 陳沂膽大酸嗆剛愎自用
# https://news.ltn.com.tw/news/entertainment/breakingnews/3169875
# 2020-05-19
# 小彭于晏神結合古典與流行   李齊把浴缸變舞台
# https://news.ltn.com.tw/news/entertainment/paper/1373518
# 2020-05-19
# 李建軒創作致敬周董 22首經典曲全入列
# https://news.ltn.com.tw/news/entertainment/paper/1373304
# 2020-05-18
# © 2020 The
# 男星巧思致敬周董 釣出本尊興奮到失眠
# https://news.ltn.com.tw/news/entertainment/breakingnews/3168455
# 2020-05-17
# 五月天御用導演為S.H.E執導MV獲國際獎項肯定
# https://news.ltn.com.tw/news/entertainment/breakingnews/3163388
# 2020-05-12
# 震撼！演唱到一半....「雙J」世紀合體掀暴動
# https://news.ltn.com.tw/news/entertainment/breakingnews/3163127
# 2020-05-12
# 周杰倫挺受虐兒 臉書遭灌爆「感謝為香港黑警虐待兒童發聲」
# https://news.ltn.com.tw/news/entertainment/breakingnews/3162345
# 2020-05-11
# 蔡淳佳選擇障礙發作 副業生意慘掉9成
# https://news.ltn.com.tw/news/entertainment/breakingnews/3161945
# 2020-05-11
# （專訪）羅時豐耍浪漫遭拒 做這事老婆爽翻
# https://news.ltn.com.tw/news/entertainment/breakingnews/3161351
# 2020-05-11
# 《人物專訪》羅時豐送戒愛妻搞飛機 兒瘋頑童猛推老爸合作
# https://news.ltn.com.tw/news/entertainment/paper/1371699
# 2020-05-11
# 周遊記搞怪變裝 周杰倫&quot;玩&quot;出人情味
# https://news.ltn.com.tw/news/entertainment/paper/1371326
# 2020-05-09
# 周董登上《美聯社》！五月天阿信成「鐵粉」狂追
# https://news.ltn.com.tw/news/entertainment/breakingnews/3159546
# 2020-05-08
# 女力無敵！雅慕斯娛樂7女星合體分享抗疫祕方
# https://news.ltn.com.tw/news/entertainment/breakingnews/3154840
# 2020-05-04
# 周杰倫餐廳宣告歇業 13年回憶月底退場
# https://news.ltn.com.tw/news/entertainment/breakingnews/3152527
# 2020-05-02
# 震驚！周杰倫「Mr.J」餐廳宣布歇業 原因曝光令人不捨
# https://news.ltn.com.tw/news/entertainment/breakingnews/3152497
# 2020-05-02
# 曹楊演活葉湘倫 周董欽點當師弟-劇團男主角出單曲 拍MV挑戰獨角戲
# https://news.ltn.com.tw/news/entertainment/paper/1369277
# 2020-04-30
# 《胡如虹和她的藝人朋友們》婁峻碩就愛嘻哈  勇賭COLORFUL未來
# https://news.ltn.com.tw/news/entertainment/paper/1368566
# 2020-04-27
# 羅志祥熱愛收藏 港媒爆：最貴名錶可買大樓
# https://news.ltn.com.tw/news/entertainment/breakingnews/3145172
# 2020-04-25
# © 2020 The
# Done
