# %%
#coding:utf-8
#65001
import requests
import lxml.html
import json
import codecs
import sys
import argparse as ap
import time

# def argParse():
#     parser=ap.ArgumentParser(description='Mobile01 Crawler')
#     parser.add_argument("cid", help="Mobile01 Category ID")
#     parser.add_argument("pages", help="Pages")
#     return parser.parse_args()

# args=argParse()
# cid = args.cid
# pages = args.pages

cid = '27'
pages = '2'
rs = requests.session()

def start_requests():
    urls = []
    for i in range(1,int(pages)+1):
        str_idx = ''+('%s' % i)
        uri = 'https://www.mobile01.com/forumtopic.php?c='+cid+'&p='+str_idx+''
        print(uri)
        urls.append(uri)

    for url in urls:
        print (url)
        parseMobile01(url)
        time.sleep(0.5)

def request_uri(uri):
    header = {"User-Agent": 'Mozilla/5.0 (Windows NT 10.0; WOW64; rv:51.0)'}
    res = rs.get(uri, headers=header)
    html_data =  res.text
    return html_data

def parseMobile01(uri):
    html_data =  request_uri(uri)
    title = ''
    link = ''
    
    selector = lxml.html.document_fromstring(html_data)
    newslist = selector.xpath('/html/body/div/main/div[1]/div[2]/div/div/div[1]/div[7]/div/div[2]/div/div[2]/div')
    for i in range(len(newslist)):
        str_idx = str(i+1)
        # 公告/置頂
        title_path = '/html/body/div/main/div[1]/div/div/div/div[1]/div[7]/div/div[2]/div/div[2]/div['+str_idx+']/div[1]/div/div[2]/a//text()'
        title = selector.xpath(title_path)
        title = ''.join(title)
        if len(title.strip())==0:
            title_path = '/html/body/div/main/div[1]/div/div/div/div[1]/div[7]/div/div[2]/div/div[2]/div['+str_idx+']/div[1]/div/div/a//text()'
            title = selector.xpath(title_path)
            title = ''.join(title)
        link_path = '/html/body/div/main/div[1]/div/div/div/div[1]/div[7]/div/div[2]/div/div[2]/div['+str_idx+']/div[1]/div/div[2]/a//@href'
        link = selector.xpath(link_path)
        link = ''.join(link)
        if len(link.strip())==0:
            link_path = '/html/body/div/main/div[1]/div/div/div/div[1]/div[7]/div/div[2]/div/div[2]/div['+str_idx+']/div[1]/div/div/a//@href'
            link = selector.xpath(link_path)
            link = ''.join(link)
        link = 'https://www.mobile01.com/'+link
        print(title)
        print(link)
        items.append([title, link])

if __name__ == '__main__':
    items = []
    start_requests();
    row_json = json.dumps(dict(items), ensure_ascii=False)
    file = codecs.open(cid+'.json', 'w', encoding='utf-8')
    file.write(row_json)
    file.close()
    print("Done")
# Out:
# https://www.mobile01.com/forumtopic.php?c=27&p=1
# https://www.mobile01.com/forumtopic.php?c=27&p=2
# https://www.mobile01.com/forumtopic.php?c=27&p=1
# 減脂減過頭 瘦到胸部......
# https://www.mobile01.com/topicdetail.php?f=215&t=6102124
# 孩子的線上課程要如何挑選？
# https://www.mobile01.com/topicdetail.php?f=375&t=6096178
# 最近大家戴口罩還會想買彩妝嗎?
# https://www.mobile01.com/topicdetail.php?f=371&t=6101392
# 幾歲開始抗皺?
# https://www.mobile01.com/topicdetail.php?f=372&t=6102765
# 武漢肺炎破三百例了，大家有從這次疫情學到什麼嗎?(經驗交流一下!)
# https://www.mobile01.com/topicdetail.php?f=375&t=6065445
# 持續便秘能否嘗試水解奶粉？
# https://www.mobile01.com/topicdetail.php?f=375&t=6098848
# 雷射術前功課
# https://www.mobile01.com/topicdetail.php?f=372&t=6100946
# 小孩吃的益生菌該怎麼挑?
# https://www.mobile01.com/topicdetail.php?f=375&t=6099081
# 小孩能乖乖使用3C嗎...
# https://www.mobile01.com/topicdetail.php?f=375&t=6102496
# 女生最容易囤貨的5樣美妝品
# https://www.mobile01.com/topicdetail.php?f=373&t=6081722
# Avent 吸乳器開箱~真心好用
# https://www.mobile01.com/topicdetail.php?f=375&t=6100597
# 大家到底是吃蛋糕還是砸蛋糕？
# https://www.mobile01.com/topicdetail.php?f=375&t=6098164
# 請問有推薦的醫美診所嗎?
# https://www.mobile01.com/topicdetail.php?f=372&t=6101995
# 分享~讓孩子在家玩科學的好物
# https://www.mobile01.com/topicdetail.php?f=375&t=6102661
# 各種禮盒買過一次
# https://www.mobile01.com/topicdetail.php?f=375&t=6098534
# 幫孩子改變飲食習慣
# https://www.mobile01.com/topicdetail.php?f=375&t=6102389
# 大家推薦做皮秒去斑嗎?
# https://www.mobile01.com/topicdetail.php?f=215&t=6102001
# 10分鐘懶人の日常微醺妝
# https://www.mobile01.com/topicdetail.php?f=371&t=6101429
# 問:含香精的保養品對肌膚的傷害
# https://www.mobile01.com/topicdetail.php?f=372&t=6103153
# 嘴邊肉垂垂的，推薦埋線拉提嗎??會痛嗎??
# https://www.mobile01.com/topicdetail.php?f=373&t=6052151
# 夏天適合的洗卸產品？
# https://www.mobile01.com/topicdetail.php?f=372&t=6102226
# 這週年禮讓我露出不失禮貌的笑容
# https://www.mobile01.com/topicdetail.php?f=215&t=6102772
# 初老的煩惱…降低皺紋產生保濕真的很重要！（內有圖慎入）
# https://www.mobile01.com/topicdetail.php?f=372&t=6097717
# 益生菌品牌請教～
# https://www.mobile01.com/topicdetail.php?f=375&t=6101308
# 好奇媽咪們挑選奶粉的重點是什麼?
# https://www.mobile01.com/topicdetail.php?f=375&t=6102611
# 新版更好用！敏感肌也可以放心的隔離乳
# https://www.mobile01.com/topicdetail.php?f=372&t=6095054
# 臉上的痘痘讓我好害怕照鏡子...
# https://www.mobile01.com/topicdetail.php?f=372&t=6089582
# 【開箱】日系私密處保養品MAPUTI使用心得
# https://www.mobile01.com/topicdetail.php?f=372&t=6101481
# 請求保養品推薦
# https://www.mobile01.com/topicdetail.php?f=372&t=6101545
# 異膚寶寶照顧小心得分享～
# https://www.mobile01.com/topicdetail.php?f=375&t=6098280
# https://www.mobile01.com/forumtopic.php?c=27&p=2
# 翻身好吵，求推薦抗干擾的床墊和新北店家
# https://www.mobile01.com/topicdetail.php?f=375&t=6101165
# 以為年輕時的熱愛能持續到永久
# https://www.mobile01.com/topicdetail.php?f=215&t=6083746
# 小孩進入第一個叛逆期了真的很難教 難道只有我是焦慮媽嗎？
# https://www.mobile01.com/topicdetail.php?f=375&t=6102834
# 大家有推薦好用的美白抗痘身體乳嗎
# https://www.mobile01.com/topicdetail.php?f=372&t=6096336
# 淡斑美白真得要靠雷射嗎?
# https://www.mobile01.com/topicdetail.php?f=372&t=6098425
# 坐月子會帶行李箱去嗎？
# https://www.mobile01.com/topicdetail.php?f=375&t=6102274
# 有推薦的雨靴品牌嗎?
# https://www.mobile01.com/topicdetail.php?f=373&t=6099113
# 年底婚禮前想去打星皮秒，有人打過嗎?
# https://www.mobile01.com/topicdetail.php?f=373&t=6076484
# 懷孕如何養胎不養肉
# https://www.mobile01.com/topicdetail.php?f=375&t=6081969
# 保養必備品有哪些?
# https://www.mobile01.com/topicdetail.php?f=372&t=6096141
# 防疫少出門 肥肉找上門ＱＱ
# https://www.mobile01.com/topicdetail.php?f=372&t=6095523
# 爬山曬黑惹!!!...可以吃什麼補救回來嗎?!
# https://www.mobile01.com/topicdetail.php?f=372&t=6095818
# 思波綺髮膜真的有那麼好用?
# https://www.mobile01.com/topicdetail.php?f=372&t=6103005
# 夏天就是得用冰冰涼涼的保養品啊
# https://www.mobile01.com/topicdetail.php?f=372&t=6093906
# 去健身房運動，都怎麼帶沐浴用品？
# https://www.mobile01.com/topicdetail.php?f=372&t=6096267
# 有沒有喝不胖的手搖茶阿
# https://www.mobile01.com/topicdetail.php?f=215&t=6101790
# 出門化妝時間?
# https://www.mobile01.com/topicdetail.php?f=371&t=6102756
# 寶寶要開始吃副食品了，芽米寶貝評價OK嗎?
# https://www.mobile01.com/topicdetail.php?f=375&t=6095327
# 想買美妝給女友但選不出要哪類
# https://www.mobile01.com/topicdetail.php?f=371&t=6057984
# 男生女生購物大不同，HAPPYGO pay統計女人比較會省錢
# https://www.mobile01.com/topicdetail.php?f=373&t=6101628
# 有沒有人也在保養品罐上寫編號?
# https://www.mobile01.com/topicdetail.php?f=372&t=6097899
# 好聞的去油洗髮精？
# https://www.mobile01.com/topicdetail.php?f=372&t=6084398
# 新手推靠得住棉條 不會失手～～
# https://www.mobile01.com/topicdetail.php?f=215&t=6099169
# 分享~寶寶便祕改善s26鉑臻心得
# https://www.mobile01.com/topicdetail.php?f=375&t=6102075
# 喜歡用的底妝類型?
# https://www.mobile01.com/topicdetail.php?f=371&t=6098450
# 高雄月子中心價格跟比較的問題
# https://www.mobile01.com/topicdetail.php?f=375&t=6081015
# 男戒推薦品牌
# https://www.mobile01.com/topicdetail.php?f=215&t=6096740
# 醫美術後的保養品怎麼選擇？
# https://www.mobile01.com/topicdetail.php?f=215&t=6101948
# 吃過什麼營養品覺得不錯的
# https://www.mobile01.com/topicdetail.php?f=372&t=6089082
# 縫/割雙眼皮哪個比較自然，台中有建議診所嗎?
# https://www.mobile01.com/topicdetail.php?f=372&t=6027473
# Done
