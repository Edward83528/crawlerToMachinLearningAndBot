# %% [markdown]
# ## request 爬蟲雛形建構-爬facebook

# %%
#!/usr/bin/env python
# -*- coding: utf-8 -*-
#65001
import requests

def request_uri(uri):
    html_data = ''
    cookie = {'key':'value', 'key':'value','key':'value'}  # 從Chrome裡取出Cookie
    try:
        header = {"User-Agent": 'Mozilla/5.0 (iPhone; CPU iPhone OS 6_1_4 like Mac OS X) AppleWebKit/536.26 (KHTML, like Gecko) Version/6.0 Mobile/10B350 Safari/8536.25'}
        res = requests.get(uri, headers=header, cookies=cookie) #加入headers模擬瀏覽器
        html_data =  res.text
    except Exception as e:
        print(str(e))
        pass
    return html_data


def start_requests(uri):
    html_data =  request_uri(uri)
    print(html_data)


if __name__ == '__main__':
    start_requests('https://m.facebook.com/jay/posts/10157688123843976');
    print("Done")
# Out:
# <!DOCTYPE html><html><head><title>周杰倫 Jay Chou 在 2018年8月30日發佈的貼文</title><meta name="viewport" content="user-scalable=no,initial-scale=1,maximum-scale=1" /><link href="https://static.xx.fbcdn.net/rsrc.php/v3/yj/r/mGy7AcZ-WAS.png" rel="apple-touch-icon-precomposed" sizes="114x114" /><meta name="referrer" content="default" id="meta_referrer" /><link type="text/css" rel="stylesheet" href="https://static.xx.fbcdn.net/rsrc.php/v3/yS/l/0,cross/OHDY8JzL4Yr.css?_nc_x=Ij3Wp8lg5Kz" data-bootloader-hash="CaGO7" /><link type="text/css" rel="stylesheet" href="https://static.xx.fbcdn.net/rsrc.php/v3/yH/l/0,cross/X1SXknoYW9I.css?_nc_x=Ij3Wp8lg5Kz" data-bootloader-hash="addYT" /><link type="text/css" rel="stylesheet" href="https://static.xx.fbcdn.net/rsrc.php/v3/yI/l/0,cross/76i63ecZe7G.css?_nc_x=Ij3Wp8lg5Kz" data-bootloader-hash="qJicj" /><script id="u_0_z" nonce="44mXLvJg">function envFlush(a){function b(b){for(var c in a)b[c]=a[c]}window.requireLazy?window.requireLazy(["Env"],b):(window.Env=window
# ...
