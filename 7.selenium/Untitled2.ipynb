# %%
# 蝦皮查詢商品
import os
import time
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.common.exceptions import TimeoutException
 
# available since 2.4.0
from selenium.webdriver.support.ui import WebDriverWait
 
# available since 2.26.0
from selenium.webdriver.support import expected_conditions as EC

prefs = {"profile.default_content_setting_values.notifications" : 2}

# open the browser with options
print("===\nopen the browser\n===\n\n\n")
chrome_options = Options()
# chrome_options.add_argument('--dns-prefetch-disable')
# chrome_options.add_argument('--no-sandbox')
# chrome_options.add_argument('--lang=en-US')
# chrome_options.add_argument('--headless')

# 停用瀏覽器上的顯示提醒 Notification 功能
chrome_options.add_argument("--disable-notifications")
chrome_options.add_argument("--start-maximized")
#chrome_options.add_experimental_option('prefs', {'intl.accept_languages': 'en-US', 'default_content_setting_values': {'notifications': 2}} )
chrome_options.add_experimental_option("prefs",prefs)

# browser = webdriver.Chrome(executable_path='D:/Programming/Python/Selenium/assets/chromedriver.exe', chrome_options=chrome_options)
# browser = webdriver.Chrome(executable_path='D:/Programming/Python/Selenium/assets/geckodriver.exe', chrome_options=chrome_options)
driver = webdriver.Chrome('assets/chromedriver.exe', chrome_options=chrome_options)
# makes sure slower connections work as well        
print ("Waiting 10 sec")
driver.implicitly_wait(10)

# 開啟 蝦皮
driver.get("https://shopee.tw/")

# 顯示標題
print(driver.title)

#重新整理網頁
driver.refresh()

time.sleep(2)
# 找到搜尋框
# inputElement = driver.find_elements_by_class_name("shopee-searchbar-input__input")
# 以上會回傳list，是錯誤的寫法!

# 寫法一: 不適合
#inputElement = driver.find_element_by_xpath('.//*[@id="main"]/div/div[2]/div[1]/div/div[2]/div/div[1]/div[1]/div/form/input')

# 寫法二: 找尋id或class的名稱
inputElement = driver.find_element_by_xpath(".//*[@class='shopee-searchbar-input__input']")

# 其他可用尋找的方法
# find_elements_by_id
# find_elements_by_class_name

# 搜尋框輸入字
inputElement.send_keys("鐵三角 ATH-AR5BT")
#inputElement.send_keys("DavidLanz site:jumpin.cc")

# 送出查詢 (錯誤的表單，因為採用的是DOM)
#inputElement.submit()

# 按下按鈕
inputElement = driver.find_element_by_xpath('.//*[@id="main"]/div/div[2]/div[1]/div/div[2]/div/div[1]/div[1]/button')
#driver.find_element_by_css_selector("[class^='btn btn-solid-primary']").click()
#inputElement = driver.find_element_by_xpath("//button[.='送出']") # 若按鈕有文字的話
inputElement.click()

try:
    # 直到標題有 ATH-AR5BT (小寫: ath-ar5bt)
    WebDriverWait(driver, 10).until(EC.title_contains("ath-ar5bt"))
 
    # 顯示標題，可看到 ATH-AR5BT
    print(driver.title)
    #存下畫面圖檔
    time.sleep(2)
    driver.save_screenshot('Selenium05_screenshots.png')
    
    productElement = driver.find_element_by_xpath('//*[@id="main"]/div/div[2]/div[1]/div/div[2]/div/div[1]/div[1]/button')
    #h4[class='entry-title'] > a
    #a[class='post-thumbnail']
    #//div[@class="listRight"]/ul/li/h2/a/text()
    #//div[@class="listRight"]/ul/li/h2/a/@href
    #//div[@class="listRight"]/ul/li/div/time/@datetime
    #//html/body/dt/a/img/@src
    #//*[@class="one"]/ul/li
    #//span[@class='class']

    list_item = driver.find_elements_by_xpath("//*[contains(@class,'shopee-search-item-result__item')]")
    print(len(list_item))
    for x in list_item:
        print(x.text)

except TimeoutException:
    print('time out')
finally:
    driver.quit()
    pass
# Out:
# ===
# open the browser
# ===
# C:\Users\u0151051\Anaconda3\lib\site-packages\ipykernel_launcher.py:32: DeprecationWarning: use options instead of chrome_options
# Waiting 10 sec
# 蝦皮購物 | 花得更少買得更好
# 鐵三角 ath-ar5bt - 優惠推薦 - 2020年5月 |蝦皮購物台灣
# 51
# 廣告
# 【音樂趨勢】Astrotec阿思翠 Phoenix 鳳凰座 旗艦 雙靜電單體+動圈單體 耳機(現貨)
# $29,990
# 台北市中山區
# 蝦皮優選
# 廣告
# 🔺六角🔺現貨 台灣保固半年 金屬 重低音 磁吸 有線 入耳式 耳機 iPhone 耳機 Andorid 適用線控
# 3 件 9.5折
# $169
# 已售出 1,792
# 桃園市楊梅區
# 蝦皮優選
# 8.6
# 折
# 廣告
# 現貨直出➤終身保固 高音質精品耳機 49101 UX201 紀卜心推薦 耳機 入耳式 耳塞式 重低音 低音
# $950 - $1,340
# 已售出 2,385
# 新北市淡水區
# 蝦皮優選
# 5.8
# 折
# 廣告
# 適用於B&O Beoplay H9i/H9/H8/H7/H6/H4耳機收納包 收納盒 包耳式耳機盒 硬殼便攜抗壓包
# 2 件 9.8折
# $252 - $303
# 已售出 101
# 台北市大安區
# 蝦皮優選
# 5.8
# 折
# 廣告
# 「鐵三角ATH-MSR7羊皮耳罩」適用於陌生人妻真皮耳機套 M50X M40 M30 M20羊皮耳套 蛋白皮套 一對裝
# 2 件 9.8折
# $160 - $490
# 已售出 238
# 台北市大安區
# 鐵三角 ATH-AR5BT/無線/耳罩/耳機（現量特價紅色）
# $6,500
# 台北市信義區
# 現貨 適用于鐵三角ATH-AR3BT AR3IS AR5BT AR5IS耳機套 海綿套耳套耳罩AAA
# $238 - $268
# PK86耳機套 海綿皮套 如Audio-technica 鐵三角 ATH-AR5 AR5iS AR5BT
# $550
# 已售出 3
# 台北市萬華區
# 9.5
# 折
# ❤特價下殺❤SONY MDR-7506 V6 鐵三角AR3BT AR5BT IS 寶華P7 P9耳機包 收納盒w11/7
# $238
# $226
# 現貨 適用鐵三角AR5BT IS MSR7b ES700 ES10 W9 耳機頭梁保護套 橫梁墊AAA
# $180
# audio-technica 鐵三角 原廠保固一年 ATH-AR5BT 藍牙無線 耳罩式耳機 無線耳機
# $5,280
# 嘉義市東區
# AFO福利品 鐵三角ATH-AR5BT 耳罩式耳機 展示機
# $1,585 - $4,285
# 已售出 1
# 新北市板橋區
# 6
# 折
# 1對用於ATH-AR5BT AR5IS耳機的柔軟海綿蓋皮革耳塞式耳墊
# $280
# $168
# 海外
# 鐵三角 ATH-AR5BT 無線耳罩式耳機 絕地音樂樂器中心
# $8,000
# 鐵三角 無限藍芽耳機 ATH - AR5BT
# $5,500
# 基隆市中正區
# 廣告
# 【音樂趨勢】Astrotec阿思翠 Phoenix 鳳凰座 旗艦 雙靜電單體+動圈單體 耳機(現貨)
# $29,990
# 台北市中山區
# 蝦皮優選
# 廣告
# 🔺六角🔺現貨 台灣保固半年 金屬 重低音 磁吸 有線 入耳式 耳機 iPhone 耳機 Andorid 適用線控
# 3 件 9.5折
# $169
# 已售出 1,792
# 桃園市楊梅區
# 蝦皮優選
# 8.6
# 折
# 廣告
# 現貨直出➤終身保固 高音質精品耳機 49101 UX201 紀卜心推薦 耳機 入耳式 耳塞式 重低音 低音
# $950 - $1,340
# 已售出 2,385
# 新北市淡水區
# 蝦皮優選
# 5.8
# 折
# 廣告
# 適用於B&O Beoplay H9i/H9/H8/H7/H6/H4耳機收納包 收納盒 包耳式耳機盒 硬殼便攜抗壓包
# 2 件 9.8折
# $252 - $303
# 已售出 101
# 台北市大安區
# 蝦皮優選
# 5.8
# 折
# 廣告
# 「鐵三角ATH-MSR7羊皮耳罩」適用於陌生人妻真皮耳機套 M50X M40 M30 M20羊皮耳套 蛋白皮套 一對裝
# 2 件 9.8折
# $160 - $490
# 已售出 238
# 台北市大安區
# 鐵三角 ATH-AR5BT/無線/耳罩/耳機（現量特價紅色）
# $6,500
# 台北市信義區
# 現貨 適用于鐵三角ATH-AR3BT AR3IS AR5BT AR5IS耳機套 海綿套耳套耳罩AAA
# $238 - $268
# PK86耳機套 海綿皮套 如Audio-technica 鐵三角 ATH-AR5 AR5iS AR5BT
# $550
# 已售出 3
# 台北市萬華區
# 9.5
# 折
# ❤特價下殺❤SONY MDR-7506 V6 鐵三角AR3BT AR5BT IS 寶華P7 P9耳機包 收納盒w11/7
# $238
# $226
# 現貨 適用鐵三角AR5BT IS MSR7b ES700 ES10 W9 耳機頭梁保護套 橫梁墊AAA
# $180
# audio-technica 鐵三角 原廠保固一年 ATH-AR5BT 藍牙無線 耳罩式耳機 無線耳機
# $5,280
# 嘉義市東區
# AFO福利品 鐵三角ATH-AR5BT 耳罩式耳機 展示機
# $1,585 - $4,285
# 已售出 1
# 新北市板橋區
# 6
# 折
# 1對用於ATH-AR5BT AR5IS耳機的柔軟海綿蓋皮革耳塞式耳墊
# $280
# $168
# 海外
# 鐵三角 ATH-AR5BT 無線耳罩式耳機 絕地音樂樂器中心
# $8,000
# 鐵三角 無限藍芽耳機 ATH - AR5BT
# $5,500
# 基隆市中正區
