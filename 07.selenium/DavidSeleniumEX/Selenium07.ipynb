# %%
# Mobile01
import os
import time
from bs4 import BeautifulSoup as bs
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.common.exceptions import TimeoutException
 
# available since 2.4.0
from selenium.webdriver.support.ui import WebDriverWait
 
# available since 2.26.0
from selenium.webdriver.support import expected_conditions as EC


prefs = {"profile.default_content_setting_values.notifications" : 2}

# open the browser with options
print("===\nopen the browser\n===\n\n\n")
chrome_options = Options()
# chrome_options.add_argument('--dns-prefetch-disable')
# chrome_options.add_argument('--no-sandbox')
# chrome_options.add_argument('--lang=en-US')
# chrome_options.add_argument('--headless')

# 停用瀏覽器上的顯示提醒 Notification 功能
chrome_options.add_argument("--disable-notifications")
# chrome_options.add_argument("--start-maximized")
#chrome_options.add_experimental_option('prefs', {'intl.accept_languages': 'en-US', 'default_content_setting_values': {'notifications': 2}} )
chrome_options.add_experimental_option("prefs",prefs)
driver = webdriver.Chrome('assets/chromedriver.exe', chrome_options=chrome_options)

# makes sure slower connections work as well        
print ("Waiting 10 sec")
driver.implicitly_wait(10)

# 開啟網址
driver.get("https://www.mobile01.com/forumtopic.php?c=16&p=1")

# 顯示標題
print(driver.title)

#重新整理網頁
driver.refresh()

time.sleep(2)

try:
    # 直到標題有 Mobile01
    WebDriverWait(driver, 10).until(EC.title_contains("Mobile01"))
 
    # TO DO
    html_data =  driver.page_source
    soup = bs(html_data,'html.parser')
    for div_soup in soup.findAll('div', attrs={"class":"c-listTableTd__title"}):
        title = ""
        link = ""
        for a_soup in div_soup.findAll('a', attrs={"class":"c-link u-ellipsis"}):
            title = a_soup.getText()
            link = "https://www.mobile01.com/{}".format(a_soup.get('href'))
            print(title)
            print(link)
        #print(div_soup)
        #print("="*20)

except TimeoutException:
    print('time out')
finally:
    # driver.quit()
    pass
# Out:
# ===
# open the browser
# ===
# C:\Users\u0151051\Anaconda3\lib\site-packages\ipykernel_launcher.py:31: DeprecationWarning: use options instead of chrome_options
# Waiting 10 sec
# 手機 - Mobile01
# [公告] 智慧型與傳統手機各版面發文公告規則 (2017年09月14日更新)
# https://www.mobile01.com/topicdetail.php?f=61&t=3036682
# 在直營店簽約的消費糾紛
# https://www.mobile01.com/topicdetail.php?f=18&t=6099821
# 2020 Whoscall 推薦序號分享
# https://www.mobile01.com/topicdetail.php?f=423&t=6036261
# 5G手機有缺頻問題嗎??
# https://www.mobile01.com/topicdetail.php?f=18&t=6104001
# 紅米NOTE 9 PRO簡易開箱
# https://www.mobile01.com/topicdetail.php?f=634&t=6104059
# Samsung Note9 面板掛了
# https://www.mobile01.com/topicdetail.php?f=568&t=5999087
# Xperia 1 II 吸引你的地方有哪些呢？有什麼害怕的痛點嗎？
# https://www.mobile01.com/topicdetail.php?f=569&t=6103560
# 使用whoscall發現輸入別人的推薦序號可以獲得30天進階離線辨識的功能，天數可以累計，輸1筆30天，輸2筆60天(不知道有沒有上限...)所以有使用whoscall的朋友歡迎大家把自己的推薦序號貼上來分享越多人貼大家的免費天數就都可以越多～我的推薦序號：KB99SA
# https://www.mobile01.com/topicdetail.php?f=566&t=5692620
# ...
