# %% [markdown]
# # 擷取Mobile01資料存入MongoDB

# %%
#coding:utf-8
#65001
import requests
import json
import codecs
import sys
import argparse as ap
import time
import pymongo as mg
import datetime
import lxml.html

# def argParse():
#     parser=ap.ArgumentParser(description='Mobile01 Crawler')
#     parser.add_argument("cid", help="Mobile01 Category ID")
#     parser.add_argument("pages", help="Pages")
#     return parser.parse_args()

# args=argParse()
# cid = args.cid
# pages = args.pages

cid = "27"
pages = "1"

rs = requests.session()
client = mg.MongoClient('127.0.0.1:27017')
db = client['mobile01']

def start_requests():
    urls = []
    for i in range(1,int(pages)+1):
        str_idx = ''+('%s' % i)
        urls.append('https://www.mobile01.com/forumtopic.php?c='+cid+'&p='+str_idx+'')

    for url in urls:
        print (url)
        parseMobile01(url)
        time.sleep(0.5)

def request_uri(uri):
    header = {"User-Agent": 'Mozilla/5.0 (Windows NT 10.0; WOW64; rv:51.0)'}
    res = rs.get(uri, headers=header)
    html_data =  res.text
    return html_data

def parseMobile01(uri):
    html_data =  request_uri(uri)
    title = ''
    link = ''
    items=[]
    selector = lxml.html.document_fromstring(html_data)
    newslist = selector.xpath('/html/body/div/main/div[1]/div/div/div/div[1]/div[7]/div/div[2]/div/div[2]/div')
    for i in range(len(newslist)):
        str_idx = str(i+1)
        # 公告/置頂
        title_path = '/html/body/div/main/div[1]/div/div/div/div[1]/div[7]/div/div[2]/div/div[2]/div['+str_idx+']/div[1]/div/div[2]/a//text()'
        title = selector.xpath(title_path)
        title = ''.join(title)
        if len(title.strip())==0:
            title_path = '/html/body/div/main/div[1]/div/div/div/div[1]/div[7]/div/div[2]/div/div[2]/div['+str_idx+']/div[1]/div/div/a//text()'
            title = selector.xpath(title_path)
            title = ''.join(title)
        link_path = '/html/body/div/main/div[1]/div/div/div/div[1]/div[7]/div/div[2]/div/div[2]/div['+str_idx+']/div[1]/div/div[2]/a//@href'
        link = selector.xpath(link_path)
        link = ''.join(link)
        if len(link.strip())==0:
            link_path = '/html/body/div/main/div[1]/div/div/div/div[1]/div[7]/div/div[2]/div/div[2]/div['+str_idx+']/div[1]/div/div/a//@href'
            link = selector.xpath(link_path)
            link = ''.join(link)
        link = 'https://www.mobile01.com/'+link
        print(title)
        print(link)
        result = db.urllib.insert_one(
          {
              "title": title,
              "link":link,
              "datetime":datetime.datetime.now()
          })
        items.append([title, link])

if __name__ == '__main__':
    start_requests();
    print("Done")
# Out:
# https://www.mobile01.com/forumtopic.php?c=27&p=1
# 最近在kidsroom買東西，左右為難了
# https://www.mobile01.com/topicdetail.php?f=375&t=6104165
# 寶寶 一夜的哭鬧 該怎辦 (慌張的新手爸爸)
# https://www.mobile01.com/topicdetail.php?f=375&t=888098
# 大家運動會穿壓力褲嗎?有人聽說過婭薇恩的加壓飛塑褲跟加壓輕盈飛飆褲嗎?哪個穿起來比較舒服?還是有其他推薦的!!!
# https://www.mobile01.com/topicdetail.php?f=372&t=6073488
# 請問有關護手霜
# https://www.mobile01.com/topicdetail.php?f=215&t=333299
# 依妍熹的仙女機有人用過嗎
# https://www.mobile01.com/topicdetail.php?f=215&t=6104125
# 指尖脫皮
# https://www.mobile01.com/topicdetail.php?f=372&t=6038153
# 防武漢病毒~大家都用酒精消毒嗎?
# https://www.mobile01.com/topicdetail.php?f=215&t=6053918
# 有人也是手乾的嚴重嗎？
# https://www.mobile01.com/topicdetail.php?f=372&t=6043605
# 尿布啊，尿布
# https://www.mobile01.com/topicdetail.php?f=375&t=2317560
# 幫女朋友挑護手霜
# https://www.mobile01.com/topicdetail.php?f=372&t=6045935
# 大家月經來是用什麼生理用品呢？
# https://www.mobile01.com/topicdetail.php?f=215&t=6084559
# 朋友生小孩的紅包
# https://www.mobile01.com/topicdetail.php?f=375&t=6103935
# 如何讓小孩在家放電
# https://www.mobile01.com/topicdetail.php?f=375&t=6102141
# 請問一下為什麼陰道沒啥感覺呢?
# https://www.mobile01.com/topicdetail.php?f=215&t=6103515
# 請問大家都怎麼收納買很多的衣服呢?
# https://www.mobile01.com/topicdetail.php?f=373&t=6104235
# 天氣好爛，想帶孩子出門很懶，有沒有推薦的室內活動？
# https://www.mobile01.com/topicdetail.php?f=375&t=6104238
# 最近大家戴口罩還會想買彩妝嗎?
# https://www.mobile01.com/topicdetail.php?f=371&t=6101392
# 曬斑除了皮秒雷射有其他除斑雷射推薦嗎?之前有反黑的狀況，想問美仕媞的光繞雷射除斑效果好嗎?
# https://www.mobile01.com/topicdetail.php?f=372&t=6098145
# 防疫少出門 肥肉找上門ＱＱ
# https://www.mobile01.com/topicdetail.php?f=372&t=6095523
# 愛水媽媽的保健食品清單
# https://www.mobile01.com/topicdetail.php?f=372&t=6101287
# 小姪子愛吃草莓
# https://www.mobile01.com/topicdetail.php?f=375&t=6104204
# 大家有拇指外翻問題做手術的嗎
# https://www.mobile01.com/topicdetail.php?f=373&t=6101963
# 有甚麼 換季期間可以鎮定肌膚保養品???
# https://www.mobile01.com/topicdetail.php?f=372&t=6099256
# 馨朵拉的紫馨抗痘凝膠這個母嬰品牌有媽媽用過嗎?還是有推薦其他媽媽可用的抗痘凝膠?大家用法會厚敷還是薄擦阿~~
# https://www.mobile01.com/topicdetail.php?f=372&t=6092242
# 找月子中心找得心好累...
# https://www.mobile01.com/topicdetail.php?f=375&t=6092182
# 建議使用上上肌的一瓶水金露做日常基礎保養品之一嗎?
# https://www.mobile01.com/topicdetail.php?f=372&t=6104195
# 請求保養品推薦
# https://www.mobile01.com/topicdetail.php?f=372&t=6101545
# Diono 3RXT安全座椅開箱，總算可在後座放3個安全座椅了!!!
# https://www.mobile01.com/topicdetail.php?f=375&t=5877428
# [分享]假性近視的治療~使用超低濃度散瞳劑0.003125%atropine效果
# https://www.mobile01.com/topicdetail.php?f=375&t=1321285
# 坐月子會帶行李箱去嗎？
# https://www.mobile01.com/topicdetail.php?f=375&t=6102274
# Done
