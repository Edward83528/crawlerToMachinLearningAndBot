# %%
#coding:utf-8
#65001
import urllib.request
import json
import codecs
import sys
import argparse as ap
import time
import datetime
import requests
from bs4 import BeautifulSoup as bs
from urllib.parse import quote

#python main.py 八仙塵爆 2015-06-27 2015-08-24 1
#def argParse():
#    parser=ap.ArgumentParser(description='Liberty Time Net Crawler')
#    parser.add_argument("keyword", help="Serch Keyword")
#    parser.add_argument("start_date", help="Start (2017-01-01)")
#    parser.add_argument("end_date", help="End (2017-01-02)")
#    parser.add_argument("pages", help="Pages")
#    return parser.parse_args()

#args=argParse()
#keyword = quote(args.keyword)
#start_date = args.start_date
#end_date = args.end_date
#pages = args.pages

keyword = quote('八仙塵爆')
start_date = '2015-06-27'
end_date = '2015-08-24'
pages = '1'

def start_requests():
    if( len(start_date.split("-"))==3 and len(end_date.split("-"))==3) :
        SYear = start_date.split("-")[0]
        SMonth = start_date.split("-")[1]
        SDay = start_date.split("-")[2]
        EYear = end_date.split("-")[0]
        EMonth = end_date.split("-")[1]
        EDay = end_date.split("-")[2]
        urls = []
        for i in range(1,int(pages)+1):
            str_idx = ''+('%s' % i)
            urls.append('http://news.ltn.com.tw/search?keyword='+keyword+'&conditions=and&SYear='+SYear+'&SMonth='+SMonth+'&SDay='+SDay+'&EYear='+EYear+'&EMonth='+EMonth+'&EDay='+EDay+'&page='+str_idx+'')

        for url in urls:
            print (url)
            parseLtnNews(url)
            time.sleep(0.5)
    else:
        print ("Data format error.")

        
def request_uri(uri):
    header = {"User-Agent": 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.36'}
    rs = requests.session()
    res = rs.get(uri, headers=header)
    html_data =  res.text
    #r = requests.post(url=uri, headers={'Connection':'close'})
    return html_data


def parseLtnNews(uri):
    postdate = ""
    link = ""
    title = ""
    body = ""
    html_data =  request_uri(uri)
    soup = bs(html_data,'html.parser')
    for ul_soup in soup.findAll('ul',attrs={"id":"newslistul"}):
        for span_soup in ul_soup.findAll('span'):
            postdate = span_soup.string.replace("&nbsp;","")[:10]
        for li_soup in ul_soup.findAll('li'):
            p_list = li_soup.findAll('p')
            body=p_list[1].getText()
            items.append({"uri":uri,"body":body,"updatetime":datetime.datetime.now().strftime('%Y-%m-%d')})
            #print({"uri":uri,"body":body,"updatetime":datetime.datetime.now().strftime('%Y-%m-%d')})
        #TO DO

    
    

    

if __name__ == '__main__':
    items = []
    start_requests();
    row_json = json.dumps(items, ensure_ascii=False)
    file = codecs.open(urllib.parse.unquote(keyword)+'.json', 'w', encoding='utf-8')
    file.write(row_json)
    file.close()
  

    print("Done")
# Out:
# http://news.ltn.com.tw/search?keyword=%E5%85%AB%E4%BB%99%E5%A1%B5%E7%88%86&conditions=and&SYear=2015&SMonth=06&SDay=27&EYear=2015&EMonth=08&EDay=24&page=1
# {'body': '舉行中元普度法會，昨天舉行豎幡儀式，昭告「好兄弟」前來法會「聽經聞法」，享用供品，現場也替八仙塵爆罹難者設牌位超度。\r\n昨天豎幡儀式由先嗇宮董事長李乾龍、輪值爐主奕壽里長周政宏...', 'uri': 'http://news.ltn.com.tw/search?keyword=%E5%85%AB%E4%BB%99%E5%A1%B5%E7%88%86&conditions=and&SYear=2015&SMonth=06&SDay=27&EYear=2015&EMonth=08&EDay=24&page=1', 'updatetime': '2018-03-07'}
# {'body': '〔即時新聞／綜合報導〕八仙塵爆即將屆滿2個月，許多傷患仍在醫院接受治療、復健，傷者之一的蛋糕師傅林獻桐靠著堅強意志力，即將出院，林獻桐也說，經過這次的事件，未來一定多花時間陪老...', 'uri': 'http://news.ltn.com.tw/search?keyword=%E5%85%AB%E4%BB%99%E5%A1%B5%E7%88%86&conditions=and&SYear=2015&SMonth=06&SDay=27&EYear=2015&EMonth=08&EDay=24&page=1', 'updatetime': '2018-03-07'}
# {'body': '〔即時新聞／綜合報導〕藝人秦偉昨前往中國醫藥大學附設醫院欲探視八仙塵爆傷患，但因非三等親遭院方拒絕，竟在醫院內咆哮，影片PO網後引起撻伐。秦偉今表示，希望外界將心比心，傷患只希...', 'uri': 'http://news.ltn.com.tw/search?keyword=%E5%85%AB%E4%BB%99%E5%A1%B5%E7%88%86&conditions=and&SYear=2015&SMonth=06&SDay=27&EYear=2015&EMonth=08&EDay=24&page=1', 'updatetime': '2018-03-07'}
# {'body': '文／曾涵郁\r\n去年的高雄氣爆和今年的八仙塵爆意外，增加不少燒燙傷病患，如能適當補充營養，將有助於傷口癒合及早日康復。\r\n◎熱量\r\n燒燙傷病患所需熱量跟年齡、性別、體重和燒燙傷面...', 'uri': 'http://news.ltn.com.tw/search?keyword=%E5%85%AB%E4%BB%99%E5%A1%B5%E7%88%86&conditions=and&SYear=2015&SMonth=06&SDay=27&EYear=2015&EMonth=08&EDay=24&page=1', 'updatetime': '2018-03-07'}
# {'body': '由1名女歌迷以6萬元得標，林昕陽宣布要將該筆款項捐給陽光基金會，並演唱《眼裡的陽光》，鼓勵八仙塵爆的傷患：「希望他們能堅強，趕快復元好起來。」...', 'uri': 'http://news.ltn.com.tw/search?keyword=%E5%85%AB%E4%BB%99%E5%A1%B5%E7%88%86&conditions=and&SYear=2015&SMonth=06&SDay=27&EYear=2015&EMonth=08&EDay=24&page=1', 'updatetime': '2018-03-07'}
# {'body': '〔記者翁聿煌／新北報導〕八仙塵爆即將屆滿兩個月，在雙和醫院治療的呂紹熙昨天出院，醫院醫護人員特別為他準備廿歲生日蛋糕，提前歡度生日及出院歡送會，院方表示，呂紹熙積極的態度，是對...', 'uri': 'http://news.ltn.com.tw/search?keyword=%E5%85%AB%E4%BB%99%E5%A1%B5%E7%88%86&conditions=and&SYear=2015&SMonth=06&SDay=27&EYear=2015&EMonth=08&EDay=24&page=1', 'updatetime': '2018-03-07'}
# {'body': '〔記者翁聿煌／新北報導〕八仙塵爆即將屆滿兩個月，在雙和醫院治療的呂紹熙今天出院，醫護人員特別為他準備20歲生日蛋糕，提前歡度生日及出院歡送會，恭喜紹熙經歷急診入院、清創、植皮、...', 'uri': 'http://news.ltn.com.tw/search?keyword=%E5%85%AB%E4%BB%99%E5%A1%B5%E7%88%86&conditions=and&SYear=2015&SMonth=06&SDay=27&EYear=2015&EMonth=08&EDay=24&page=1', 'updatetime': '2018-03-07'}
# {'body': '、冤親債主等好好享用一番。\r\n今年廟方以「功德海」慈航普度大法船為主軸，盼讓近來接連發生的八仙塵爆、天津爆炸、泰國爆炸案等受難者，可以乘著法船脫離苦海，並開放信眾到圍繞法船周圍...', 'uri': 'http://news.ltn.com.tw/search?keyword=%E5%85%AB%E4%BB%99%E5%A1%B5%E7%88%86&conditions=and&SYear=2015&SMonth=06&SDay=27&EYear=2015&EMonth=08&EDay=24&page=1', 'updatetime': '2018-03-07'}
# {'body': '，已有超過16萬人次在二姊演唱會上透過她的歌聲得到感動，每場台上台下都有感人故事，昨晚更有八仙塵爆傷者王捷垠坐著輪椅來看演出，他原本就搶買到二姊的門票，卻因塵爆受傷住院，他曾樂...', 'uri': 'http://news.ltn.com.tw/search?keyword=%E5%85%AB%E4%BB%99%E5%A1%B5%E7%88%86&conditions=and&SYear=2015&SMonth=06&SDay=27&EYear=2015&EMonth=08&EDay=24&page=1', 'updatetime': '2018-03-07'}
# {'body': '〔記者蔡淑媛、賴筱桐／綜合報導〕全身四十五％燒傷的八仙塵爆傷者宋亭緯昨天出院，直呼：「活著不是一件簡單的事，要好好珍惜！」至於奇蹟男孩呂意銘，其全身燒傷九十％未經植皮已減少到十...', 'uri': 'http://news.ltn.com.tw/search?keyword=%E5%85%AB%E4%BB%99%E5%A1%B5%E7%88%86&conditions=and&SYear=2015&SMonth=06&SDay=27&EYear=2015&EMonth=08&EDay=24&page=1', 'updatetime': '2018-03-07'}
# {'body': '調結果，朱立倫的施政不滿意度是上任以來最高的一次。TVBS民調中心分析認為，風災救災不力、八仙塵爆事件處理狀況，以及面對國民黨內提名的態度，都有可能是影響這次調查結果的原因。...', 'uri': 'http://news.ltn.com.tw/search?keyword=%E5%85%AB%E4%BB%99%E5%A1%B5%E7%88%86&conditions=and&SYear=2015&SMonth=06&SDay=27&EYear=2015&EMonth=08&EDay=24&page=1', 'updatetime': '2018-03-07'}
# {'body': '〔記者蔡淑媛／台中報導〕八仙塵爆傷者宋亭緯全身四十五%燒傷，今天出院，直呼「活著不是一件簡單的事，要好好珍惜！」感謝醫護人員呵護，也鼓勵傷友一起加油，回家後他將持續復健也能上學...', 'uri': 'http://news.ltn.com.tw/search?keyword=%E5%85%AB%E4%BB%99%E5%A1%B5%E7%88%86&conditions=and&SYear=2015&SMonth=06&SDay=27&EYear=2015&EMonth=08&EDay=24&page=1', 'updatetime': '2018-03-07'}
# {'body': '賦予她的權力，把宜蘭的醫療資源都刪光，並舉燒傷病床為例，原要配置的4個燒傷病床也被刪除，而八仙塵爆卻有11名宜蘭年輕人受傷。並問道：「洪秀柱女士，您對您乾爸爸之外的宜蘭人說句話...', 'uri': 'http://news.ltn.com.tw/search?keyword=%E5%85%AB%E4%BB%99%E5%A1%B5%E7%88%86&conditions=and&SYear=2015&SMonth=06&SDay=27&EYear=2015&EMonth=08&EDay=24&page=1', 'updatetime': '2018-03-07'}
# {'body': '\n\n\n\n\n\n〔記者陳慧玲／台北報導〕「二姊一定會等著你的。」7月中的一句約定，讓八仙塵爆傷者帶著二姊的鼓勵努力復健，今晚「二姊」江蕙在小巨蛋的第15場「祝福」演唱會，傷者王捷垠...', 'uri': 'http://news.ltn.com.tw/search?keyword=%E5%85%AB%E4%BB%99%E5%A1%B5%E7%88%86&conditions=and&SYear=2015&SMonth=06&SDay=27&EYear=2015&EMonth=08&EDay=24&page=1', 'updatetime': '2018-03-07'}
# {'body': '〔記者賴筱桐／新北報導〕八仙塵爆發生至今近2個月，媒體報導，檢警經密集實驗，排除菸蒂、靜電、打火機等因素，認為燈光束高溫加上民眾奔逃擾動氣流，助長高密度粉塵引燃爆炸。但上述推論...', 'uri': 'http://news.ltn.com.tw/search?keyword=%E5%85%AB%E4%BB%99%E5%A1%B5%E7%88%86&conditions=and&SYear=2015&SMonth=06&SDay=27&EYear=2015&EMonth=08&EDay=24&page=1', 'updatetime': '2018-03-07'}
# Done
