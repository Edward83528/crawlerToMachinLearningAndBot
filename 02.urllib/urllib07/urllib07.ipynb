# %% [markdown]
# # urllib - split - Mobile01 多版別、多頁 - 輸出JSON檔案

# %%
#coding:utf-8
#65001
import urllib.request
import json
import codecs
import sys
import argparse as ap
import time

# def argParse():
#     parser=ap.ArgumentParser(description='Mobile01 Crawler')
#     parser.add_argument("cid", help="Mobile01 Category ID")
#     parser.add_argument("pages", help="Pages")
#     return parser.parse_args()

# args=argParse()
# cid = args.cid
# pages = args.pages

cid = '27'
pages = '2'

def start_requests():
    urls = []
    for i in range(1,int(pages)+1):
        str_idx = ''+('%s' % i)
        urls.append('https://www.mobile01.com/forumtopic.php?c='+cid+'&p='+str_idx+'')

    for url in urls:
        print (url)
        parseMobile01(url)
        time.sleep(0.5)

def parseMobile01(uri):
    req = urllib.request.Request(
        uri, 
        data=None, 
        headers={
            'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_3) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/35.0.1916.47 Safari/537.36'
        }
    )
    handle = urllib.request.urlopen(req)
    encoding = handle.headers.get_content_charset()
    html_data =  handle.read().decode(encoding)
    title = ''
    link = ''
    
    for a in html_data.split('l-listTable__td">')[1:]:
        if 'o-hashtag is-mini is-default' in a:
            # 公告
            link = 'https://www.mobile01.com/'+a.split('href="')[1].split('"')[0]
            title = a.split('c-link u-ellipsis" >')[1].split('</')[0]
        if 'o-hashtag is-mini is-heightLight' in a:
            # 置頂文
            link = 'https://www.mobile01.com/'+a.split('href="')[1].split('"')[0]
            title = a.split('c-link u-ellipsis" >')[1].split('</')[0]
        elif 'l-listTable__tbody' not in a:
            # 非置頂文, 中間有發現標頭的部分不處理
            link = 'https://www.mobile01.com/'+a.split('href="')[1].split('"')[0]
            title = a.split('c-link u-ellipsis" >')[1].split('</')[0]
        if len(title)>0 and len(link)>0:
            items.append([title, link])
        

if __name__ == '__main__':
    items = []
    start_requests();
    row_json = json.dumps(dict(items), ensure_ascii=False)
    file = codecs.open('out.json', 'w', encoding='utf-8')
    file.write(row_json)
    file.close()
    print("Done")
# Out:
# https://www.mobile01.com/forumtopic.php?c=27&p=1
# https://www.mobile01.com/forumtopic.php?c=27&p=2
# Done

# %%
jObj = json.loads(row_json)
# print(jObj)
for x in jObj:
    print(x)
    print(jObj[x])
# Out:
# 求推薦值得團購的好用保濕/美白面膜牌子
# https://www.mobile01.com/topicdetail.php?f=372&t=6069499
# 要怎麼讓男友多在意自己一些
# https://www.mobile01.com/topicdetail.php?f=215&t=6064505
# 結婚後老公還會幫你拿包包嗎？
# https://www.mobile01.com/topicdetail.php?f=215&t=6069057
# 安全感會隨著年紀的增長而減少嗎？
# https://www.mobile01.com/topicdetail.php?f=215&t=6069037
# 大家會傳照片跟另一半分享自己在幹嘛嗎？
# https://www.mobile01.com/topicdetail.php?f=215&t=6066060
# 終於要坐完月子了，心美力要繼續喝嗎？
# https://www.mobile01.com/topicdetail.php?f=375&t=6069085
