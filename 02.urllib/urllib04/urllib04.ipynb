# %% [markdown]
# # urllib - split - Mobile01 區分置頂文與內文

# %%
#coding:utf-8
#65001
import urllib.request
import time

def start_requests():
    urls = [
        'https://www.mobile01.com/forumtopic.php?c=16&p=1',
        'https://www.mobile01.com/forumtopic.php?c=16&p=2',
    ]
    for url in urls:
        time.sleep(1)
        parseMobile01(url)

def parseMobile01(uri):
    req = urllib.request.Request(
        uri, 
        data=None, 
        headers={ #告訴server 我是瀏覽器
            'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_3) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/35.0.1916.47 Safari/537.36'
        }
    )
    handle = urllib.request.urlopen(req)
    encoding = handle.headers.get_content_charset()
    html_data =  handle.read().decode(encoding)
    title = ''
    link = ''
    for a in html_data.split('c-listTableTd__title">')[1:]:
        link = 'https://www.mobile01.com/'+a.split('href="')[1].split('"')[0]
        title = a.split('c-link u-ellipsis" >')[1].split('</')[0]
        print(title)
        print(link)

if __name__ == '__main__':
    start_requests()
    print("Done")
# Out:
# [公告] 智慧型與傳統手機各版面發文公告規則 (2017年09月14日更新)
# https://www.mobile01.com/topicdetail.php?f=61&t=3036682
# 【史上最6旗艦機】性能全新再進化開拓星感受！即刻報名搶先體驗Galaxy S20 5G系列
# https://www.mobile01.com/topicdetail.php?f=568&t=6042785
# 有買台版Watch GT2的，建議連上對岸運動健康伺服器
# https://www.mobile01.com/topicdetail.php?f=738&t=6067073
# 小米的效率實在太差
# https://www.mobile01.com/topicdetail.php?f=634&t=6069411
# 華為P40系列發表 相機新亮點：手機已經可以做到10倍光學變焦了啊...（還可以拍野生動物紀錄片）
# https://www.mobile01.com/topicdetail.php?f=629&t=6055024
# S20全系列賣不動,驚傳三星砍單三成
# https://www.mobile01.com/topicdetail.php?f=568&t=6069441
# 中華續約438吃到飽，門市介紹最低還有388
# https://www.mobile01.com/topicdetail.php?f=18&t=6036849
# 其實Acer手機CP值很高，但台灣好像比較小人在用
# https://www.mobile01.com/topicdetail.php?f=564&t=5814080
# google相簿分類
# https://www.mobile01.com/topicdetail.php?f=18&t=6067645
# 只要一個門號收簡訊
# https://www.mobile01.com/topicdetail.php?f=18&t=6069241
# Mix2s 藍芽耳機通話時，其他APP會沒聲音
# https://www.mobile01.com/topicdetail.php?f=634&t=6066204
# 遠傳吃到飽319不降速電銷方案
# https://www.mobile01.com/topicdetail.php?f=18&t=6008764
# 【 開箱 】小米 10 Pro 5G 旗艦手機 – 2020年高 CP 值手機推薦、優缺點大公開
# https://www.mobile01.com/topicdetail.php?f=634&t=6061944
# 請問我的zenfone selife就在開機畫面轉個不停該怎麼辦？？
# https://www.mobile01.com/topicdetail.php?f=588&t=6069255
# Xperia 1螢幕耐用性？
# https://www.mobile01.com/topicdetail.php?f=569&t=6069296
# 三星 手機過熱警告 無法開機
# https://www.mobile01.com/topicdetail.php?f=568&t=6069364
# whoscall推薦序號分享
# https://www.mobile01.com/topicdetail.php?f=423&t=5540781
# whoscall序號分享
# https://www.mobile01.com/topicdetail.php?f=423&t=5961331
# 請問有人能分享紅米 Note 8 Pro EU ROM 9.11.21嗎？
# https://www.mobile01.com/topicdetail.php?f=634&t=6069424
# 請問各位S20系列的 會透過螢幕看到指紋辨識器的黑框嗎?
# https://www.mobile01.com/topicdetail.php?f=568&t=6069350
# （開箱文）Amazfit T-Rex 智能手錶-通過12項軍事認證專為戶外運動人士打造
# https://www.mobile01.com/topicdetail.php?f=738&t=6069462
# S20系列網路延遲改善方式(經過多人測試確實有感)
# https://www.mobile01.com/topicdetail.php?f=568&t=6062388
# 台版p30更新 EMUI 10
# https://www.mobile01.com/topicdetail.php?f=629&t=5971343
# Samsung Pay &amp; 悠遊紀念卡
# https://www.mobile01.com/topicdetail.php?f=568&t=6066632
# 延長手機電池續航，4招
# https://www.mobile01.com/topicdetail.php?f=393&t=6068983
# 2020 Whoscall 推薦序號分享
# https://www.mobile01.com/topicdetail.php?f=423&t=6036261
# 用過華為的網友 如果一定要轉會 選哪家
# https://www.mobile01.com/topicdetail.php?f=629&t=6061875
# 台灣大哥大的4G對小米10pro網速影響？
# https://www.mobile01.com/topicdetail.php?f=634&t=6069336
# Oneplus 8 series 售價分享
# https://www.mobile01.com/topicdetail.php?f=586&t=6069371
# 米家多功能網關搭配的疑問?
# https://www.mobile01.com/topicdetail.php?f=634&t=6069293
# 等V60還是買G8X
# https://www.mobile01.com/topicdetail.php?f=581&t=6065013
# 關於小米max，如何破除設備鎖定呢？
# https://www.mobile01.com/topicdetail.php?f=634&t=6069180
# Google Nest Hub Max 開箱
# https://www.mobile01.com/topicdetail.php?f=565&t=6028466
# （開箱文）Amazfit Stratos 3 智能手錶-為運動而生華米旗艦級大螢幕智慧手錶
# https://www.mobile01.com/topicdetail.php?f=738&t=6069294
# Galaxy Buds+  右耳無法連接
# https://www.mobile01.com/topicdetail.php?f=568&t=6055647
# 想請教各位的小蟻、小方、米家智慧攝影機(雲台)......是如何擷取一段錄影的？
# https://www.mobile01.com/topicdetail.php?f=634&t=5806353
# [請教]手上的mate9快不行了 mate20x 5g 現在還值得買嗎？
# https://www.mobile01.com/topicdetail.php?f=629&t=6040412
# Xperia 5狀態一直出現「完成Xperia設定程序」
# https://www.mobile01.com/topicdetail.php?f=569&t=6069423
# 5CA、4CA、3CA、2CA、亞太CA手機表格整理
# https://www.mobile01.com/topicdetail.php?f=18&t=4890363
# 手機自己傳簡訊？
# https://www.mobile01.com/topicdetail.php?f=689&t=6069345
# 「米家wiha精修螺絲工具套裝」打不開
# https://www.mobile01.com/topicdetail.php?f=634&t=5592197
# 官網 S10 降價了 ! !
# https://www.mobile01.com/topicdetail.php?f=568&t=6036961
# 最新的HTC消息! 5G??
# https://www.mobile01.com/topicdetail.php?f=566&t=6066945
# 『連署』申請 OnePlus 專區
# https://www.mobile01.com/topicdetail.php?f=586&t=5661667
# 電子發票會員(全家)
# https://www.mobile01.com/topicdetail.php?f=588&t=6069352
# ASUS ZenFone 6 不能雲端備份
# https://www.mobile01.com/topicdetail.php?f=588&t=5814314
# ze620kl google無法備份
# https://www.mobile01.com/topicdetail.php?f=588&t=5498984
# 遠傳電銷1111原約優惠$299(月)不限速吃到飽
# https://www.mobile01.com/topicdetail.php?f=18&t=5948468
# 有人知道這款手機嗎
# https://www.mobile01.com/topicdetail.php?f=568&t=6069155
# 想請教一下s20有去嚴選名膜貼的人指紋解鎖有影響嗎
# https://www.mobile01.com/topicdetail.php?f=568&t=6061088
# 紅米Note8T可玩PUBG Mobile跟明日之後嗎?
# https://www.mobile01.com/topicdetail.php?f=634&t=6065466
# OPPO Ace2電競旗艦揭曉 不僅輕薄、還有40W無線充電！
# https://www.mobile01.com/topicdetail.php?f=689&t=6068401
# 求台灣之星 新朋友188序號 4/30截止的
# https://www.mobile01.com/topicdetail.php?f=18&t=6068567
# 三星公告台版S20全系列只支援5G非獨立組網NSA      不支援SA及mmWave ?
# https://www.mobile01.com/topicdetail.php?f=568&t=6051262
# 小米10 PRO 原廠出廠自帶螢幕保護貼?
# https://www.mobile01.com/topicdetail.php?f=634&t=6069047
# M8刷Android 10(Lineageos 17.1)
# https://www.mobile01.com/topicdetail.php?f=566&t=6069382
# s20系列災情與5G問題申訴
# https://www.mobile01.com/topicdetail.php?f=568&t=6054817
# HTC u ultra 隨拍
# https://www.mobile01.com/topicdetail.php?f=566&t=6069376
# 京東購買手機送貨也太久了吧
# https://www.mobile01.com/topicdetail.php?f=634&t=5957362
# REDMI 8 PRO 有自動接聽功能嗎?
# https://www.mobile01.com/topicdetail.php?f=634&t=6069014
# 小米米家液晶小黑板(手寫板)10吋
# https://www.mobile01.com/topicdetail.php?f=634&t=5979748
# 紅米note 8 pro gps 定位超弱
# https://www.mobile01.com/topicdetail.php?f=634&t=5918785
# Done
