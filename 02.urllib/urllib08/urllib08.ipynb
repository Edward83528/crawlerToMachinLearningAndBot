# %% [markdown]
# # urllib - split - 自由時報關鍵字,內文摘要 - 輸出JSON檔案

# %%
#coding:utf-8
#65001
import urllib.request
import json
import codecs
import sys
import argparse as ap
import time
import datetime
from urllib.parse import quote
#以下註解拿掉可以用py執行下參數
# def argParse():
#     parser=ap.ArgumentParser(description='Liberty Time Net Crawler')
#     parser.add_argument("keyword", help="Serch Keyword")
#     parser.add_argument("start_date", help="Start (2017-01-01)")
#     parser.add_argument("end_date", help="End (2017-01-02)")
#     parser.add_argument("pages", help="Pages")
#     return parser.parse_args()

# args=argParse()
# keyword = quote(args.keyword)
# start_date = args.start_date
# end_date = args.end_date
# pages = args.pages

keyword = quote('周杰倫')
start_date = '2020-04-14'
end_date = '2019-04-15'
pages = '2'

def start_requests():
    start_list = start_date.split("-")
    end_list = end_date.split("-")
    SYear = ''
    SMonth = ''
    SDay = ''
    EYear = ''
    EMonth = ''
    EDay = ''
    if(len(start_list)==3) and (len(end_list)==3):
        SYear = start_list[0]
        SMonth = start_list[1]
        SDay = start_list[2]
        EYear = end_list[0]
        EMonth = end_list[1]
        EDay = end_list[2]
    else:
        print ("Date format error.")
  
    urls = []
    for i in range(1,int(pages)+1):
        str_idx = ''+('%s' % i)
        #http://news.ltn.com.tw/search?keyword=蘋果&conditions=and&SYear=2018&SMonth=03&SDay=01&EYear=2018&EMonth=03&EDay=05&page=1
        api = 'http://news.ltn.com.tw/search?keyword='+keyword+'&conditions=and&SYear='+SYear+'&SMonth='+SMonth+'&SDay='+SDay+'&EYear='+EYear+'&EMonth='+EMonth+'&EDay='+EDay+'&page='+str_idx+''
        urls.append(api)
        print('http://news.ltn.com.tw/search?keyword='+keyword+'&conditions=and&SYear='+SYear+'&SMonth='+SMonth+'&SDay='+SDay+'&EYear='+EYear+'&EMonth='+EMonth+'&EDay='+EDay+'&page='+str_idx+'')
        for url in urls:
            #print (url)
            parseLtnNews(url)
            time.sleep(0.5)


def parseLtnNews(uri):
    handle = urllib.request.urlopen(uri)
    encoding = handle.headers.get_content_charset()
    html_data =  handle.read().decode(encoding)
    aryTemp01 = html_data.split('class="searchlist boxTitle"')
    if len(aryTemp01)>1:
        for a in aryTemp01[1].split('<li>'):
            title = ''
            link = ''
            body = ''
            postdate = ''
            aryTemp02 = a.split('<p>')
            if len(aryTemp02)>1:
                body = aryTemp02[1].split('</p>')[0].replace("\n","").replace("<strong>","").replace("</strong>","")
                #print(body)
            aryTemp02 = a.split('class="tit" href="')
            if len(aryTemp02)>1:
                title = aryTemp02[1].split('">')[1].split("</a>")[0].replace("\n","").replace("<strong>","").replace("</strong>","")
                print(title)
                aryTemp03 = aryTemp02[1].split('"')
                link = aryTemp03[0]
                print(link)
            aryTemp02 = a.split('<span>')
            if len(aryTemp02)>1:
                postdate = aryTemp02[1].split('</span>')[0].replace("&nbsp;","")[:10]
                print(postdate)
            if len(title)>1:
                items.append({
                    "title": title,
                    "link":link,
                    "body":body,
                    "postdate":postdate,
                    #"updatetime":datetime.datetime.now(),  # MongoDB
                    "updatetime":datetime.datetime.now().strftime('%Y-%m-%d')
                    })
        

if __name__ == '__main__':
    items = []
    start_requests();
    row_json = json.dumps(items, ensure_ascii=False)
    file = codecs.open(urllib.parse.unquote(keyword)+'.json', 'w', encoding='utf-8')
    #file = codecs.open('out.json', 'w', encoding='utf-8')
    file.write(row_json)
    file.close()
    #print(row_json)
    print("Done")
# Out:
# http://news.ltn.com.tw/search?keyword=%E5%91%A8%E6%9D%B0%E5%80%AB&conditions=and&SYear=2020&SMonth=04&SDay=14&EYear=2019&EMonth=04&EDay=15&page=1
# 周杰倫人氣太夯 高中學妹曝「學校因他停課半天」
# https://news.ltn.com.tw/news/entertainment/breakingnews/3217868
# 2020-07-04
# 周董秀跑車找亮點考倒昆凌 釣出阿信來狂賀
# https://news.ltn.com.tw/news/entertainment/breakingnews/3211730
# 2020-06-29
# 王力宏直播 獎座牆搶鋒頭
# https://news.ltn.com.tw/news/entertainment/paper/1382784
# 2020-06-29
# 曹楊手寫歌詞備10款字體 師兄周董IG助攻
# https://news.ltn.com.tw/news/entertainment/paper/1382782
# 2020-06-29
# 王力宏驚人獎座曝光 周杰倫看傻這樣說
# https://news.ltn.com.tw/news/entertainment/breakingnews/3211233
# 2020-06-28
# 台灣藝人No.1！周董IG飆破600萬 蔡依林緊追封后
# https://news.ltn.com.tw/news/entertainment/breakingnews/3210863
# 2020-06-27
# 周杰倫20年經典變身黑膠唱片 暗藏彩蛋
# https://news.ltn.com.tw/news/entertainment/paper/1381976
# 2020-06-25
# 周杰倫慶出道20年首出黑膠 暗藏不能說的秘密
# https://news.ltn.com.tw/news/entertainment/breakingnews/3207937
# 2020-06-24
# 昆凌露美背秀性感  曬周董帶娃幸福藏不住
# https://news.ltn.com.tw/news/entertainment/breakingnews/3207339
# 2020-06-24
# 「仙姑素娥」梁舒涵濕透了！《女力》靈魂交換最想變成「他」
# https://news.ltn.com.tw/news/entertainment/breakingnews/3206543
# 2020-06-23
# 天道酬勤！費玉清爆紅神曲佩佩豬也愛聽
# https://news.ltn.com.tw/news/entertainment/breakingnews/3205139
# 2020-06-22
# 網紅翻唱夯曲超狂點擊 文慧如蔡佩軒幸運發片
# https://news.ltn.com.tw/news/entertainment/paper/1381276
# 2020-06-22
# Spark暴瘦7公斤被虧皮鬆   吳卓源送金粽小鹿亂撞
# https://news.ltn.com.tw/news/entertainment/paper/1379691
# 2020-06-15
# 柯有倫現身古巴求婚聖地 周杰倫嗨唱《Mojito》曝光MV花絮
# https://news.ltn.com.tw/news/entertainment/breakingnews/3193903
# 2020-06-10
# 拍《逆戰》賣命操爆！周杰倫：不再拍導演的戲
# https://news.ltn.com.tw/news/entertainment/breakingnews/3193801
# 2020-06-10
# © 2020 The
# http://news.ltn.com.tw/search?keyword=%E5%91%A8%E6%9D%B0%E5%80%AB&conditions=and&SYear=2020&SMonth=04&SDay=14&EYear=2019&EMonth=04&EDay=15&page=2
# 周杰倫人氣太夯 高中學妹曝「學校因他停課半天」
# https://news.ltn.com.tw/news/entertainment/breakingnews/3217868
# 2020-07-04
# 周董秀跑車找亮點考倒昆凌 釣出阿信來狂賀
# https://news.ltn.com.tw/news/entertainment/breakingnews/3211730
# 2020-06-29
# 王力宏直播 獎座牆搶鋒頭
# https://news.ltn.com.tw/news/entertainment/paper/1382784
# 2020-06-29
# 曹楊手寫歌詞備10款字體 師兄周董IG助攻
# https://news.ltn.com.tw/news/entertainment/paper/1382782
# 2020-06-29
# 王力宏驚人獎座曝光 周杰倫看傻這樣說
# https://news.ltn.com.tw/news/entertainment/breakingnews/3211233
# 2020-06-28
# 台灣藝人No.1！周董IG飆破600萬 蔡依林緊追封后
# https://news.ltn.com.tw/news/entertainment/breakingnews/3210863
# 2020-06-27
# 周杰倫20年經典變身黑膠唱片 暗藏彩蛋
# https://news.ltn.com.tw/news/entertainment/paper/1381976
# 2020-06-25
# 周杰倫慶出道20年首出黑膠 暗藏不能說的秘密
# https://news.ltn.com.tw/news/entertainment/breakingnews/3207937
# 2020-06-24
# 昆凌露美背秀性感  曬周董帶娃幸福藏不住
# https://news.ltn.com.tw/news/entertainment/breakingnews/3207339
# 2020-06-24
# 「仙姑素娥」梁舒涵濕透了！《女力》靈魂交換最想變成「他」
# https://news.ltn.com.tw/news/entertainment/breakingnews/3206543
# 2020-06-23
# 天道酬勤！費玉清爆紅神曲佩佩豬也愛聽
# https://news.ltn.com.tw/news/entertainment/breakingnews/3205139
# 2020-06-22
# 網紅翻唱夯曲超狂點擊 文慧如蔡佩軒幸運發片
# https://news.ltn.com.tw/news/entertainment/paper/1381276
# 2020-06-22
# Spark暴瘦7公斤被虧皮鬆   吳卓源送金粽小鹿亂撞
# https://news.ltn.com.tw/news/entertainment/paper/1379691
# 2020-06-15
# 柯有倫現身古巴求婚聖地 周杰倫嗨唱《Mojito》曝光MV花絮
# https://news.ltn.com.tw/news/entertainment/breakingnews/3193903
# 2020-06-10
# 拍《逆戰》賣命操爆！周杰倫：不再拍導演的戲
# https://news.ltn.com.tw/news/entertainment/breakingnews/3193801
# 2020-06-10
# © 2020 The
# 【兩性異言堂】〈愛唷傷腦筋〉前男友炸喜帖 妳去不去?
# https://news.ltn.com.tw/news/supplement/paper/1378593
# 2020-06-10
# 周董新歌注入古巴風情 Mojito撩舞魂 骨董車助攻MV
# https://news.ltn.com.tw/news/entertainment/paper/1378310
# 2020-06-09
# 不能只有阿信聽到！周杰倫釋出新歌濃濃古巴風情
# https://news.ltn.com.tw/news/entertainment/breakingnews/3191201
# 2020-06-08
# 罷韓通過》李佳芬故鄉雲林出現「水龍捲」！ 網驚呼
# https://news.ltn.com.tw/news/politics/breakingnews/3189701
# 2020-06-06
# 鄧紫棋億級棒 3首神曲追平周董
# https://news.ltn.com.tw/news/entertainment/paper/1377513
# 2020-06-05
# 鄧紫棋3首金曲破億華語女歌手第一人 追平周董紀錄
# https://news.ltn.com.tw/news/entertainment/breakingnews/3187296
# 2020-06-04
# 謝霆鋒駕骨董車伴遊 讚周杰倫王菲都單純
# https://news.ltn.com.tw/news/entertainment/paper/1377229
# 2020-06-04
# 謝霆鋒東京同框周杰倫 鬆口提王菲優點放閃
# https://news.ltn.com.tw/news/entertainment/breakingnews/3186465
# 2020-06-03
# 52歲參戰女團！伊能靜曝飛鷹三姝內情...領現金才辦事
# https://news.ltn.com.tw/news/entertainment/breakingnews/3185433
# 2020-06-03
# Spark巴士唱稻香 被封大巴代言人
# https://news.ltn.com.tw/news/entertainment/paper/1376979
# 2020-06-03
# 《人物專訪》Spark識破耶誕老人 卻篤信外星人
# https://news.ltn.com.tw/news/entertainment/paper/1376725
# 2020-06-02
# 友訊市場派大勝後下一步？台鋼王炯棻：去看周杰倫的電影
# https://news.ltn.com.tw/news/business/breakingnews/3183734
# 2020-06-01
# 曹楊MV動漫化 花美男機場催淚
# https://news.ltn.com.tw/news/entertainment/paper/1376124
# 2020-05-30
# 周杰倫師弟難過「被消失」 撕漫男吐真實心聲
# https://news.ltn.com.tw/news/entertainment/breakingnews/3181291
# 2020-05-29
# 東尼大木遭爆「硬上嫂子」 一張圖怒揭暗黑內幕
# https://news.ltn.com.tw/news/entertainment/breakingnews/3180684
# 2020-05-29
# © 2020 The
# Done
